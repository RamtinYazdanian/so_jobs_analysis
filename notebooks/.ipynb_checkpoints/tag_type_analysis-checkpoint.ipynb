# %%
from matplotlib import pyplot as plt
import numpy as np
import pickle
import pandas as pd
import os
import json
import seaborn as sns
from itertools import chain
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from collections import Counter
from datetime import datetime, timedelta
import operator
import sys
from bisect import bisect_right, bisect, bisect_left
from scipy.stats import chisquare

# %%
merged_both_after_warmup = pickle.load(open('matched_tags_dataframe.pkl', 'rb'))
matched_tag_types = pd.read_csv('/home/yazdania/so_jobs_analysis/tags_to_categorise.csv')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', -1):
    display(matched_tag_types.groupby('TagType').count())
# Out:
#                      Unnamed: 0  Index  TagName  IsVersion  IsMajorVersion
# TagType
# admin-solution       3           3      3        3          3
# admin-tool           10          10     10       10         10
# analytics-solution   5           5      5        5          5
# api                  8           8      8        8          8
# app                  1           1      1        1          1
# app-framework        1           1      1        1          1
# ar-framework         1           1      1        1          1
# audio-tool           1           1      1        1          1
# blockchain-solution  1           1      1        1          1
# build-solution       6           6      6        6          6
# build-tool           2           2      2        2          2
# cloud-connector      1           1      1        1          1
# cloud-database       1           1      1        1          1
# cloud-framework      1           1      1        1          1
# cloud-sdk            1           1      1        1          1
# cloud-solution       19          19     19       19         19
# cloud-tool           1           1      1        1          1
# cmd-tool             3           3      3        3          3
# collab-solution      3           3      3        3          3
# commerce-concept     2           2      2        2          2
# commerce-solution    1           1      1        1          1
# commerce-tool        1           1      1        1          1
# company              1           1      1        1          1
# compiler-solution    1           1      1        1          1
# compression-tool     1           1      1        1          1
# compute-framework    2           2      2        2          2
# config-format        1           1      1        1          1
# connector            13          13     13       13         13
# container-solution   7           7      7        7          7
# container-tool       1           1      1        1          1
# data-format          1           1      1        1          1
# data-solution        1           1      1        1          1
# database             4           4      4        4          4
# database-connector   1           1      1        1          1
# database-framework   1           1      1        1          1
# database-solution    1           1      1        1          1
# database-tool        1           1      1        1          1
# deployment-solution  1           1      1        1          1
# deprecated-api       1           1      1        1          1
# deprecated-library   1           1      1        1          1
# deprecated-standard  1           1      1        1          1
# dev-solution         7           7      7        7          7
# dev-tool             1           1      1        1          1
# edu-platform         1           1      1        1          1
# file-format          6           6      6        6          6
# format               5           5      5        5          5
# framework            14          14     14       14         14
# framework-concept    3           3      3        3          3
# framework-feature    14          14     14       14         14
# game-platform        1           1      1        1          1
# gfx-tool             1           1      1        1          1
# hardware             4           4      4        4          4
# hardware-concept     2           2      2        2          2
# ide                  5           5      5        5          5
# lang-concept         20          20     20       20         20
# lang-feature         40          40     40       39         39
# language             30          30     30       30         30
# library              90          90     90       90         90
# management-solution  6           6      6        6          6
# management-tool      3           3      3        3          3
# math-concept         20          20     20       20         20
# meta-language        1           1      1        1          1
# microserv-framework  2           2      2        2          2
# ml-cloud-solution    1           1      1        1          1
# ml-concept           13          13     13       13         13
# ml-framework         3           3      3        3          3
# ml-library           2           2      2        2          2
# ml-solution          12          12     12       12         12
# ml-tool              1           1      1        1          1
# mobile-framework     1           1      1        1          1
# mobile-sdk           2           2      2        2          2
# network-connector    1           1      1        1          1
# network-library      1           1      1        1          1
# network-solution     1           1      1        1          1
# os                   2           2      2        2          2
# person               1           1      1        1          1
# sdk                  2           2      2        2          2
# security-concept     5           5      5        5          5
# security-framework   4           4      4        4          4
# security-library     2           2      2        2          2
# security-software    1           1      1        1          1
# security-tool        1           1      1        1          1
# server-framework     1           1      1        1          1
# server-solution      5           5      5        5          5
# server-tool          1           1      1        1          1
# software-solution    4           4      4        4          4
# software-tool        4           4      4        4          4
# solution-feature     1           1      1        1          1
# standard             6           6      6        6          6
# survey-service       1           1      1        1          1
# tech-concept         105         105    105      105        105
# test-api             1           1      1        1          1
# test-framework       3           3      3        3          3
# test-solution        1           1      1        1          1
# ui                   2           2      2        2          2
# ui-tool              1           1      1        1          1
# versioning-concept   1           1      1        1          1
# versioning-solution  1           1      1        1          1
# vm-software          1           1      1        1          1
# vr-framework         2           2      2        2          2
# vr-game-platform     1           1      1        1          1
# vr-sdk               1           1      1        1          1
# vr-solution          1           1      1        1          1
# web-api              4           4      4        4          4
# web-client           5           5      5        4          4
# web-framework        25          25     25       25         25
# web-library          1           1      1        1          1
# web-proxy            1           1      1        1          1
# web-solution         1           1      1        1          1
# web-tool             3           3      3        3          3
# website              1           1      1        1          1
# wiki                 1           1      1        1          1

# %%
# This part was used to map tag types that were entirely wrong to their new types.
mapping = {x:x for x in matched_tag_types.TagType.unique()}
mapping.update({'build-soluton': 'build-solution',
                'collaborative-solution': 'collab-solution',
                'computation-framework': 'compute-framework',
                'crypto-concept': 'security-concept',
                'development-solution': 'dev-solution',
                'dev-stack': 'dev-solution',
                'doc': 'collab-solution',
                'gui': 'ui',
                'help-solution': 'management-solution',
                'language-implementation': 'library',
                'lbrary': 'library',
                'libray': 'library',
                'platform-feature': 'solution-feature',
                'project-solution': 'dev-solution',
                'protocol': 'standard',
                'source-control': 'versioning-solution',
                'web-server': 'server-solution'})

# %%
matched_tag_types.loc[matched_tag_types.TagType.apply(lambda x: 'web-solution' in x)]
# Out:
#      Unnamed: 0  Index       TagName       TagType IsVersion IsMajorVersion
# 203         203    203  google-sites  web-solution     False          False

# %%
# matched_tag_types['TagType'] = matched_tag_types['TagType'].apply(lambda x: mapping[x])

# %%
# matched_tag_types.to_csv('/home/yazdania/so_jobs_analysis/tags_to_categorise.csv')

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', -1):
    display(pd.merge(matched_tag_types, merged_both_after_warmup[['TagName', 'Excerpt']], on='TagName'))
# Out:
#                             TagName              TagType IsVersion  \
# 0    vuejs2                          web-framework        True
# 1    google-cloud-firestore          database             False
# 2    json.net                        web-framework        False
# 3    ionic3                          mobile-sdk           True
# 4    mongodb-query                   lang-concept         False
# 5    firebase-cloud-messaging        cloud-solution       False
# 6    pthreads                        api                  False
# 7    java-stream                     lang-feature         False
# 8    google-cloud-functions          cloud-solution       False
# 9    axios                           web-library          False
# 10   google-cloud-datastore          cloud-database       False
# 11   angular5                        web-framework        True
# 12   linq-to-entities                lang-feature         False
# 13   pyqt5                           api                  True
# 14   wxpython                        connector            False
# 15   retrofit2                       framework            True
# 16   vue-component                   lang-feature         False
# 17   azure-functions                 cloud-solution       False
# 18   automapper                      library              False
# 19   maven-3                         build-solution       True
# 20   hql                             language             False
# 21   racket                          language             False
# 22   javamail                        api                  False
# 23   python-3.6                      language             True
# 24   laravel-5.3                     web-framework        True
# 25   laravel-5.4                     web-framework        True
# 26   pymongo                         database-connector   False
# 27   c++17                           language             True
# 28   hyperledger-fabric              blockchain-solution  False
# 29   wmi                             api                  False
# 30   static-libraries                tech-concept         False
# 31   typeerror                       tech-concept         False
# 32   pytorch                         ml-framework         False
# 33   react-navigation                lang-feature         False
# 34   azure-cosmosdb                  database-solution    False
# 35   unity-container                 lang-feature         False
# 36   raspberry-pi3                   hardware             True
# 37   antlr                           framework            False
# 38   aws-api-gateway                 cloud-solution       False
# 39   lstm                            ml-concept           False
# 40   vuex                            library              False
# 41   boto3                           cloud-sdk            True
# 42   amazon-cognito                  cloud-solution       False
# 43   ionic4                          mobile-sdk           True
# 44   httpurlconnection               tech-concept         False
# 45   asp.net-core-webapi             api                  False
# 46   angular-material2               library              True
# 47   symfony4                        web-framework        True
# 48   azure-service-fabric            cloud-solution       False
# 49   postback                        tech-concept         False
# 50   laravel-5.5                     web-framework        True
# 51   angular2-forms                  lang-concept         False
# 52   azure-pipelines                 cloud-solution       False
# 53   tidyverse                       library              False
# 54   vuetify.js                      web-framework        False
# 55   ngrx                            library              False
# 56   nsis                            software-solution    False
# 57   angular2-services               lang-feature         False
# 58   xlsx                            file-format          False
# 59   keycloak                        security-framework   False
# 60   arkit                           ar-framework         False
# 61   setuptools                      library              False
# 62   roslyn                          api                  False
# 63   nuxt.js                         web-framework        False
# 64   compiler-warnings               tech-concept         False
# 65   gcloud                          lang-feature         False
# 66   okhttp                          web-client           False
# 67   soap-client                     web-client           False
# 68   emgucv                          connector            False
# 69   gremlin                         language             False
# 70   barcode-scanner                 hardware             False
# 71   iis-express                     server-solution      False
# 72   dask                            library              False
# 73   typescript-typings              lang-feature         False
# 74   resttemplate                    lang-feature         False
# 75   laravel-5.6                     web-framework        False
# 76   paramiko                        security-library     False
# 77   python-3.7                      language             True
# 78   azure-application-insights      analytics-solution   False
# 79   tidyr                           library              False
# 80   caliburn.micro                  app-framework        False
# 81   indexeddb                       lang-feature         False
# 82   react-hooks                     lang-feature         False
# 83   powermock                       library              False
# 84   amazon-sns                      cloud-solution       False
# 85   bean-validation                 framework            False
# 86   spring-webflux                  library              False
# 87   guzzle                          web-client           NaN
# 88   elf                             file-format          False
# 89   gatsby                          library              False
# 90   sha1                            security-concept     False
# 91   statsmodels                     library              False
# 92   slack-api                       api                  False
# 93   word2vec                        ml-concept           False
# 94   poco                            tech-concept         False
# 95   lex                             compiler-solution    False
# 96   image-segmentation              tech-concept         False
# 97   scala-collections               library              False
# 98   webpack-2                       build-solution       True
# 99   static-linking                  tech-concept         False
# 100  node-red                        connector            False
# 101  ini                             file-format          False
# 102  glfw                            library              False
# 103  firebase-analytics              cloud-solution       False
# 104  tensorboard                     library              False
# 105  next.js                         web-framework        False
# 106  redux-saga                      connector            False
# 107  spacy                           library              False
# 108  code-formatting                 tech-concept         False
# 109  xgboost                         library              False
# 110  jacoco                          build-solution       False
# 111  large-files                     tech-concept         False
# 112  gnupg                           security-framework   False
# 113  owl-carousel                    library              False
# 114  react-apollo                    library              False
# 115  shapefile                       format               False
# 116  azure-powershell                admin-solution       False
# 117  knex.js                         database-framework   False
# 118  chef-recipe                     lang-feature         False
# 119  netcdf                          standard             False
# 120  kubectl                         admin-solution       False
# 121  apache-zeppelin                 analytics-solution   False
# 122  private-key                     security-concept     False
# 123  android-livedata                library              False
# 124  p5.js                           library              False
# 125  cache-control                   tech-concept         False
# 126  server-sent-events              tech-concept         False
# 127  lubridate                       library              False
# 128  azure-data-lake                 cloud-solution       False
# 129  rubymine                        ide                  False
# 130  key-value-observing             tech-concept         False
# 131  cpan                            wiki                 False
# 132  androidx                        library              False
# 133  ode                             math-concept         False
# 134  gnome                           ui                   False
# 135  lattice                         library              False
# 136  razor-pages                     lang-feature         NaN
# 137  android-camera2                 library              True
# 138  unit-of-work                    tech-concept         False
# 139  keytool                         library              False
# 140  webpack-4                       build-solution       False
# 141  azure-iot-hub                   cloud-solution       False
# 142  hmac                            security-concept     False
# 143  apollo-client                   library              False
# 144  traefik                         connector            False
# 145  autofill                        tech-concept         False
# 146  scikit-image                    library              False
# 147  arcore                          framework            False
# 148  epoch                           tech-concept         False
# 149  junit5                          test-framework       True
# 150  amazon-athena                   cloud-solution       False
# 151  httpserver                      tech-concept         False
# 152  visual-studio-2019              ide                  True
# 153  rbenv                           library              False
# 154  rdp                             standard             False
# 155  diacritics                      tech-concept         False
# 156  jsonpath                        lang-concept         False
# 157  gradient-descent                math-concept         False
# 158  force-layout                    lang-concept         False
# 159  mcrypt                          security-library     False
# 160  gradle-plugin                   build-solution       False
# 161  minikube                        server-solution      False
# 162  java-11                         language             True
# 163  glew                            library              False
# 164  ionic-native                    framework            False
# 165  csproj                          file-format          False
# 166  sas-macro                       meta-language        False
# 167  informatica-powercenter         data-solution        False
# 168  cpython                         library              False
# 169  azure-api-management            cloud-solution       False
# 170  access-denied                   tech-concept         False
# 171  react-native-navigation         library              False
# 172  google-cloud-ml                 ml-cloud-solution    False
# 173  tfs2017                         dev-solution         False
# 174  avx                             language             False
# 175  autoencoder                     ml-concept           False
# 176  dlib                            library              False
# 177  keep-alive                      tech-concept         False
# 178  tslint                          lang-feature         False
# 179  ramda.js                        library              False
# 180  autosuggest                     tech-concept         False
# 181  android-keystore                lang-feature         False
# 182  virtuemart                      software-solution    False
# 183  android-jetpack                 library              False
# 184  apollo-server                   server-solution      False
# 185  neon                            language             False
# 186  sparkr                          library              False
# 187  spring-cloud-config             cloud-solution       False
# 188  istio                           management-solution  False
# 189  opensuse                        os                   False
# 190  arm-template                    lang-feature         False
# 191  vue-cli                         lang-feature         False
# 192  serial-communication            tech-concept         False
# 193  openshift-origin                container-solution   False
# 194  ambari                          management-solution  False
# 195  docker-for-windows              container-solution   False
# 196  iphone-x                        hardware             True
# 197  actioncable                     library              False
# 198  aws-iot                         connector            False
# 199  ngrx-store                      library              False
# 200  azure-virtual-network           network-solution     False
# 201  azure-machine-learning-studio   ml-solution          False
# 202  web3                            web-framework        False
# 203  google-sites                    web-solution         False
# 204  monad-transformers              tech-concept         False
# 205  ngx-bootstrap                   connector            False
# 206  mgo                             connector            False
# 207  azure-stream-analytics          analytics-solution   False
# 208  postgresql-9.6                  database             True
# 209  image-compression               tech-concept         False
# 210  dynamics-365                    management-solution  False
# 211  php-7.2                         language             True
# 212  laravel-mix                     web-api              False
# 213  semantic-ui-react               library              False
# 214  http-authentication             tech-concept         False
# 215  google-play-console             admin-tool           False
# 216  grid-search                     ml-concept           False
# 217  cucumber-java                   collab-solution      False
# 218  amazon-sagemaker                ml-solution          False
# 219  data-fitting                    math-concept         False
# 220  firedac                         library              False
# 221  topojson                        format               False
# 222  sinch                           sdk                  False
# 223  specs2                          library              False
# 224  ngrx-effects                    library              False
# 225  mxnet                           ml-framework         False
# 226  automata                        math-concept         False
# 227  aidl                            language             False
# 228  eigenvalue                      math-concept         False
# 229  node-sass                       connector            False
# 230  hibernate-annotations           lang-feature         False
# 231  unix-socket                     connector            False
# 232  angular-template                lang-feature         False
# 233  rvalue                          tech-concept         False
# 234  react-native-firebase           library              False
# 235  kotlin-android-extensions       library              False
# 236  cntk                            library              False
# 237  netlify                         deployment-solution  False
# 238  powerapps                       software-solution    False
# 239  tpl-dataflow                    library              False
# 240  react-router-redux              library              False
# 241  kotlin-coroutines               library              False
# 242  web-push                        web-api              False
# 243  numerical-integration           math-concept         False
# 244  coreml                          ml-framework         False
# 245  bulma                           web-framework        False
# 246  web3js                          library              False
# 247  functional-dependencies         tech-concept         False
# 248  truffle                         dev-solution         False
# 249  tensorflow.js                   ml-library           False
# 250  azure-automation                management-solution  False
# 251  netstat                         admin-tool           False
# 252  mapstruct                       lang-feature         False
# 253  oidc                            connector            False
# 254  managed-c++                     deprecated-standard  False
# 255  ansible-inventory               solution-feature     False
# 256  google-vr                       vr-framework         False
# 257  apostrophe                      tech-concept         False
# 258  richtext                        tech-concept         False
# 259  error-code                      tech-concept         False
# 260  aws-codebuild                   software-solution    False
# 261  yolo                            library              False
# 262  powershell-ise                  ide                  False
# 263  zoho                            company              False
# 264  azure-cognitive-services        ml-solution          False
# 265  django-2.0                      web-framework        True
# 266  ngrok                           web-proxy            False
# 267  partial-classes                 tech-concept         False
# 268  uicontrol                       framework-feature    False
# 269  mockmvc                         framework-feature    False
# 270  frameset                        lang-feature         False
# 271  amazon-lex                      ml-solution          False
# 272  undertow                        server-solution      False
# 273  memory-barriers                 tech-concept         False
# 274  net-http                        web-api              False
# 275  c#-7.0                          language             True
# 276  joi                             lang-feature         False
# 277  p-value                         math-concept         False
# 278  watchdog                        tech-concept         False
# 279  fixed-point                     tech-concept         False
# 280  pundit                          library              False
# 281  opcode                          tech-concept         False
# 282  windows-firewall                security-software    False
# 283  android-instrumentation         lang-feature         False
# 284  vmware-workstation              vm-software          False
# 285  workbox                         server-solution      False
# 286  algebraic-data-types            tech-concept         False
# 287  web-api-testing                 tech-concept         False
# 288  surveymonkey                    survey-service       False
# 289  replicaset                      lang-concept         False
# 290  java-module                     lang-feature         False
# 291  superagent                      web-api              False
# 292  save-as                         tech-concept         False
# 293  secret-key                      security-concept     False
# 294  .net-core-2.0                   web-framework        True
# 295  php4                            language             True
# 296  aws-serverless                  cloud-solution       False
# 297  laravel-dusk                    test-api             False
# 298  azure-kubernetes                container-solution   False
# 299  azure-api-apps                  cloud-solution       False
# 300  tfs2018                         dev-solution         True
# 301  orc                             format               False
# 302  pwm                             tech-concept         False
# 303  rpa                             tech-concept         False
# 304  changeset                       tech-concept         False
# 305  firebase-cli                    admin-tool           False
# 306  swift5                          language             True
# 307  wit.ai                          ml-solution          False
# 308  django-1.11                     web-framework        True
# 309  azure-container-service         container-solution   False
# 310  wavelet                         math-concept         False
# 311  mern                            dev-solution         False
# 312  rssi                            tech-concept         False
# 313  inode                           tech-concept         False
# 314  react-context                   lang-feature         False
# 315  holoviews                       library              False
# 316  ecmascript-2017                 language             True
# 317  aot                             lang-feature         False
# 318  arcmap                          software-tool        False
# 319  maven-failsafe-plugin           framework-feature    False
# 320  read-the-docs                   collab-solution      False
# 321  django-2.1                      web-framework        True
# 322  sightly                         language             False
# 323  np-complete                     math-concept         False
# 324  prisma                          connector            False
# 325  snort                           security-tool        False
# 326  heroku-cli                      admin-tool           False
# 327  geotiff                         standard             False
# 328  hyperparameters                 ml-concept           False
# 329  http-response-codes             tech-concept         False
# 330  css-variables                   lang-concept         False
# 331  browser-plugin                  web-tool             False
# 332  jigsaw                          framework            False
# 333  runtime-permissions             lang-feature         False
# 334  aws-codecommit                  versioning-solution  False
# 335  fabric8                         management-solution  False
# 336  qt3d                            library              False
# 337  dot-product                     math-concept         False
# 338  multinomial                     math-concept         False
# 339  zipkin                          server-tool          False
# 340  dbeaver                         database-tool        False
# 341  windows-10-desktop              ui                   False
# 342  elastica                        library              False
# 343  saga                            tech-concept         False
# 344  background-subtraction          tech-concept         False
# 345  element-ui                      library              False
# 346  kotlin-extension                lang-concept         False
# 347  dotnet-cli                      admin-tool           False
# 348  ack                             software-tool        False
# 349  c++-concepts                    language             True
# 350  ipfs                            standard             False
# 351  batch-normalization             ml-concept           False
# 352  mixed-content                   tech-concept         False
# 353  spatial-index                   tech-concept         False
# 354  jenkins-slave                   framework-concept    False
# 355  reactive-forms                  framework-concept    False
# 356  bloc                            tech-concept         False
# 357  go-ethereum                     library              False
# 358  eiffel                          language             False
# 359  quantization                    tech-concept         False
# 360  splitter                        tech-concept         False
# 361  otrs                            management-solution  False
# 362  msg                             file-format          False
# 363  mle                             ml-concept           False
# 364  swift-package-manager           build-tool           False
# 365  data-partitioning               tech-concept         False
# 366  docker-swarm-mode               framework-feature    False
# 367  cryptocurrency                  security-concept     False
# 368  centroid                        math-concept         False
# 369  design-by-contract              tech-concept         False
# 370  eeprom                          hardware             False
# 371  scss-mixins                     lang-feature         False
# 372  vbox                            lang-feature         False
# 373  lottie                          library              False
# 374  nano                            ide                  False
# 375  serde                           framework            False
# 376  bacon.js                        library              False
# 377  directory-listing               tech-concept         False
# 378  generative-adversarial-network  ml-concept           False
# 379  django-1.10                     web-framework        True
# 380  image-caching                   tech-concept         False
# 381  geth                            library              False
# 382  kvc                             tech-concept         False
# 383  seq2seq                         library              False
# 384  reentrancy                      tech-concept         False
# 385  recompose                       library              False
# 386  blazemeter                      test-solution        False
# 387  ftp-server                      tech-concept         False
# 388  ico                             file-format          False
# 389  fasttext                        ml-library           False
# 390  mongodb-replica-set             lang-feature         False
# 391  watson-assistant                ml-solution          False
# 392  servo                           hardware-concept     False
# 393  non-deterministic               math-concept         False
# 394  webpack-3                       build-tool           True
# 395  kestrel                         library              False
# 396  m4                              language             False
# 397  html-validation                 tech-concept         False
# 398  jwt-auth                        standard             False
# 399  monorepo                        tech-concept         False
# 400  color-mapping                   tech-concept         False
# 401  mixture-model                   ml-concept           False
# 402  elasticsearch-query             lang-concept         False
# 403  circle-pack                     math-concept         False
# 404  ff                              library              False
# 405  persistent-volumes              framework-feature    False
# 406  forex                           commerce-concept     False
# 407  session-scope                   lang-concept         False
# 408  aws-sam                         cloud-framework      False
# 409  readxl                          library              False
# 410  opencv-python                   deprecated-library   False
# 411  cloudify                        cloud-solution       False
# 412  pushdown-automaton              math-concept         False
# 413  polly                           library              False
# 414  typescript3.0                   language             True
# 415  daydream                        vr-solution          False
# 416  catkin                          build-solution       False
# 417  visual-recognition              ml-solution          False
# 418  redux-framework                 web-framework        False
# 419  random-walk                     math-concept         False
# 420  row-level-security              tech-concept         False
# 421  facebook-analytics              analytics-solution   False
# 422  azure-container-registry        framework-feature    False
# 423  free-monad                      tech-concept         False
# 424  bpf                             network-connector    False
# 425  jcache                          api                  False
# 426  powershell-core                 admin-tool           False
# 427  unreal-blueprint                lang-feature         False
# 428  stack-memory                    tech-concept         False
# 429  vue-material                    web-framework        False
# 430  google-slides                   cloud-tool           False
# 431  angular-elements                framework-feature    False
# 432  volusion                        commerce-solution    False
# 433  orthogonal                      math-concept         False
# 434  bounded-contexts                tech-concept         False
# 435  angular-testing                 lang-concept         False
# 436  conditional-breakpoint          tech-concept         False
# 437  pwd                             cmd-tool             False
# 438  graphframes                     library              False
# 439  tailwind-css                    web-framework        False
# 440  s-expression                    tech-concept         False
# 441  metamask                        web-tool             False
# 442  wp-cli                          admin-tool           False
# 443  app-startup                     tech-concept         False
# 444  dl4j                            library              False
# 445  pisa                            library              False
# 446  run-configuration               tech-concept         False
# 447  natural-join                    tech-concept         False
# 448  backpressure                    tech-concept         False
# 449  react-360                       vr-framework         False
# 450  google-vr-sdk                   vr-sdk               False
# 451  django-deployment               framework-concept    False
# 452  launchpad                       collab-solution      False
# 453  dropout                         ml-concept           False
# 454  deap                            compute-framework    False
# 455  amazon-quicksight               analytics-solution   False
# 456  auto-value                      lang-feature         False
# 457  cross-language                  tech-concept         False
# 458  watson-studio                   ml-solution          False
# 459  feature-descriptor              ml-concept           False
# 460  zeus                            library              False
# 461  khan-academy                    edu-platform         False
# 462  facebook-instant-games          game-platform        False
# 463  fabric.io                       mobile-framework     False
# 464  aws-ebs                         framework-feature    False
# 465  face-id                         ml-solution          False
# 466  binance                         deprecated-api       False
# 467  java-ee-8                       language             True
# 468  htop                            cmd-tool             False
# 469  specification-pattern           tech-concept         False
# 470  action-mapping                  lang-feature         False
# 471  statechart                      tech-concept         False
# 472  varray                          lang-feature         False
# 473  spectron                        test-framework       False
# 474  python-regex                    library              False
# 475  configmap                       lang-feature         False
# 476  adobe-animate                   gfx-tool             False
# 477  kitura                          server-framework     False
# 478  mpd                             audio-tool           False
# 479  redis-server                    database             False
# 480  pprof                           library              False
# 481  sku                             tech-concept         False
# 482  airtable                        database             False
# 483  model-comparison                ml-concept           False
# 484  subject-observer                tech-concept         False
# 485  deform                          library              False
# 486  python-typing                   lang-concept         False
# 487  android-device-monitor          ui-tool              False
# 488  authenticity-token              lang-feature         False
# 489  knuth                           person               False
# 490  tmpfs                           tech-concept         False
# 491  openvino                        ml-solution          False
# 492  microprofile                    microserv-framework  False
# 493  ucp                             network-library      False
# 494  archer                          dev-solution         False
# 495  idoc                            language             False
# 496  mapping-model                   tech-concept         False
# 497  snowball                        language             False
# 498  referential-transparency        tech-concept         False
# 499  dyno                            container-solution   False
# 500  kolmogorov-smirnov              math-concept         False
# 501  reportng                        library              False
# 502  aws-codestar                    cloud-solution       False
# 503  alv                             library              False
# 504  steamvr                         vr-game-platform     False
# 505  srv                             framework-feature    False
# 506  blue-green-deployment           tech-concept         False
# 507  cert-manager                    admin-solution       False
# 508  docker-engine                   container-solution   False
# 509  symfony-flex                    library              False
# 510  openvas                         security-framework   False
# 511  unit-type                       tech-concept         False
# 512  sld                             format               False
# 513  calico                          compute-framework    False
# 514  ether                           commerce-concept     False
# 515  adaptive-ui                     library              False
# 516  html-object                     lang-concept         False
# 517  chefdk                          sdk                  False
# 518  spring-io                       framework            False
# 519  pathauto                        library              False
# 520  graphql-tools                   library              False
# 521  flowable                        library              False
# 522  seneca                          library              False
# 523  private-subnet                  tech-concept         False
# 524  sling-models                    lang-concept         False
# 525  torii                           lang-feature         False
# 526  siege                           web-tool             False
# 527  highrise                        management-tool      False
# 528  mlp                             ml-concept           False
# 529  quora                           website              False
# 530  shaderlab                       language             False
# 531  cucm                            commerce-tool        False
# 532  createml                        ml-solution          False
# 533  wagon                           framework-feature    False
# 534  cold-start                      tech-concept         False
# 535  tether                          library              False
# 536  windows-server-2019             os                   True
# 537  image-viewer                    app                  False
# 538  hapi.js                         web-framework        False
# 539  raw-pointer                     tech-concept         False
# 540  ddl-trigger                     lang-concept         False
# 541  rook                            library              False
# 542  pvcs                            dev-solution         False
# 543  upx                             compression-tool     False
# 544  android-make                    lang-concept         False
# 545  decentralized-applications      tech-concept         False
# 546  radium                          library              False
# 547  canary-deployment               tech-concept         False
# 548  n3                              language             False
# 549  rcu                             tech-concept         False
# 550  pbr                             tech-concept         False
# 551  react-fullstack                 web-framework        False
# 552  nameko                          microserv-framework  False
# 553  jquery-ui-plugins               framework-feature    False
# 554  contract-first                  tech-concept         False
# 555  azure-stack                     cloud-solution       False
# 556  ispf                            management-tool      False
# 557  elasticsearch-api               lang-concept         False
# 558  unfold                          tech-concept         False
# 559  kurtosis                        math-concept         False
# 560  configuration-profile           config-format        False
# 561  insomnia                        web-client           False
# 562  react-fiber                     library              False
# 563  apex-trigger                    lang-concept         False
# 564  fiddle                          library              False
# 565  no-framework                    tech-concept         False
# 566  .net-core-1.1                   framework            True
# 567  data-access-object              tech-concept         False
# 568  reify                           tech-concept         False
# 569  p-np                            math-concept         False
# 570  pallet                          framework            False
# 571  crdt                            data-format          False
# 572  multi-catch                     lang-feature         False
# 573  automatic-failover              tech-concept         False
# 574  chgrp                           cmd-tool             False
# 575  slab                            lang-feature         False
# 576  mirage                          framework            False
# 577  git-track                       versioning-concept   False
# 578  manifold                        software-tool        False
# 579  aws-storage-gateway             cloud-connector      False
# 580  version-compatibility           tech-concept         False
# 581  account-linking                 tech-concept         False
# 582  chirp                           hardware-concept     False
# 583  message-channel                 framework-feature    False
# 584  fmt                             library              False
# 585  cactus                          test-framework       False
# 586  neutrino                        dev-tool             False
# 587  ecmascript-2016                 language             True
# 588  oracle-analytics                lang-concept         False
# 589  treeline                        web-framework        False
# 590  jakarta-ee                      dev-solution         False
# 591  docker-ee                       container-solution   False
# 592  floating-ip                     tech-concept         False
# 593  dtr                             framework-feature    False
# 594  geopackage                      format               False
# 595  argon                           web-client           False
# 596  spring-modules                  lang-concept         False
# 597  map-basic                       language             False
# 598  rls                             ide                  False
# 599  option-type                     lang-feature         False
# 600  list-processing                 tech-concept         False
# 601  connection-points               framework-feature    False
# 602  staging-table                   tech-concept         False
# 603  access-protection               tech-concept         False
# 604  reaper                          software-tool        False
# 605  zen-of-python                   tech-concept         False
# 606  npn                             standard             False
# 607  sysdig                          admin-tool           False
# 608  tia-portal                      admin-tool           False
# 609  koa.js                          framework            False
# 610  astro                           admin-tool           False
# 611  authentication-flows            security-framework   False
# 612  hibernate-query                 language             False
# 613  prototype-scope                 lang-concept         False
# 614  management-pack                 management-tool      False
# 615  haxl                            library              False
# 616  poet                            web-framework        False
# 617  code-elimination                tech-concept         False
# 618  smack-stack                     framework            False
# 619  zig                             language             False
# 620  enclose                         library              False
# 621  dfd                             tech-concept         False
# 622  codemod                         library              False
# 623  colossus                        framework            False
# 624  relationship-extraction         ml-tool              False
# 625  loadleveler                     library              False
# 626  es2018                          language             True
# 627  mix-and-match                   tech-concept         False
# 628  neptune                         ml-solution          False
# 629  dry-run                         tech-concept         False
# 630  docker-app                      container-tool       False
# 631  connect-rest                    connector            False
#
#     IsMajorVersion  \
# 0    True
# 1    False
# 2    False
# 3    True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# 10   False
# 11   True
# 12   False
# 13   True
# 14   False
# 15   True
# 16   False
# 17   False
# 18   False
# 19   True
# 20   False
# 21   False
# 22   False
# 23   False
# 24   False
# 25   False
# 26   False
# 27   True
# 28   False
# 29   False
# 30   False
# 31   False
# 32   False
# 33   False
# 34   False
# 35   False
# 36   True
# 37   False
# 38   False
# 39   False
# 40   False
# 41   True
# 42   False
# 43   True
# 44   False
# 45   False
# 46   True
# 47   True
# 48   False
# 49   False
# 50   False
# 51   False
# 52   False
# 53   False
# 54   False
# 55   False
# 56   False
# 57   False
# 58   False
# 59   False
# 60   False
# 61   False
# 62   False
# 63   False
# 64   False
# 65   False
# 66   False
# 67   False
# 68   False
# 69   False
# 70   False
# 71   False
# 72   False
# 73   False
# 74   False
# 75   False
# 76   False
# 77   False
# 78   False
# 79   False
# 80   False
# 81   False
# 82   False
# 83   False
# 84   False
# 85   False
# 86   False
# 87   NaN
# 88   False
# 89   False
# 90   False
# 91   False
# 92   False
# 93   False
# 94   False
# 95   False
# 96   False
# 97   False
# 98   True
# 99   False
# 100  False
# 101  False
# 102  False
# 103  False
# 104  False
# 105  False
# 106  False
# 107  False
# 108  False
# 109  False
# 110  False
# 111  False
# 112  False
# 113  False
# 114  False
# 115  False
# 116  False
# 117  False
# 118  False
# 119  False
# 120  False
# 121  False
# 122  False
# 123  False
# 124  False
# 125  False
# 126  False
# 127  False
# 128  False
# 129  False
# 130  False
# 131  False
# 132  False
# 133  False
# 134  False
# 135  False
# 136  NaN
# 137  True
# 138  False
# 139  False
# 140  False
# 141  False
# 142  False
# 143  False
# 144  False
# 145  False
# 146  False
# 147  False
# 148  False
# 149  True
# 150  False
# 151  False
# 152  True
# 153  False
# 154  False
# 155  False
# 156  False
# 157  False
# 158  False
# 159  False
# 160  False
# 161  False
# 162  True
# 163  False
# 164  False
# 165  False
# ...
# 598  The Rust Language Server (RLS) provides useful functionalities to IDEs, editors and other tools for Rust development, including code completion, 'goto definition', symbol search and reformatting.
# 599  The option type in F# is used when an actual value might not exist for a named value or variable. An option has an underlying type and can hold a value of that type, or it might not have a value.
# 600  List processing is a concept in many data-oriented languages that involves performing an action once for each member of a list.
# 601  Connection points are the standard COM interface exposed by connectable objects, that allows clients to register for event callbacks. This tag is for questions about implementing and registering clients with the IConnectionPoint interface.
# 602  Staging tables are used in data ETL (extraction transformation and loading) processes and data warehousing.
# 603  Restrictions that allow to protect variables from external/ unintended modification.
# 604  REAPER is digital audio workstation software: a complete multitrack audio and MIDI recording, editing, processing, mixing, and mastering environment.
# 605  Related to python best practices. A set of guiding principles for Python's code design comprising 20 aphorisms, only 19 of which have been written down; Created by Tim Peters.
# 606  The Next Protocol Negotiation extension (NPN) is currently used to negotiate the use of SPDY as an application level protocol.
# 607  Linux system exploration and troubleshooting tool with first class support for containers.
# 608  The TIA-Portal tag describes the SIMATIC STEP 7 Totally Integrated Automation Portal and is the graphical user interface for the broad range of Siemens PLCs. On this platform you can plan, program, validate, diagnose and control your written PLC program. The device database gives access to basic, advanced and distributed controllers of each generation.
# 609  A Koa application is an object containing an array of middleware generator functions which are composed and executed in a stack-like manner upon request
# 610  Some sort of file manager for android
# 611  Authentication-Flows is a powerful and highly customizable framework that covers all flows that authentication-server that is based on Spring-Security needs.
# 612  The Hibernate Query Language
# 613  A Spring specific scope used to define a Bean that will get newly created on each request.
# 614  SCOM (System Center Operation Manager) management packs. Management packs typically contain monitoring settings for applications and services. After a management pack is imported into a management group, System Center 2012 – Operations Manager immediately begins monitoring objects based on default configurations and thresholds that are set by the management pack.
# 615  Haxl is a Haskell library that simplifies access to remote data, such as databases or web-based services.
# 616  for questions about Poet, a web framework for Mason
# 617  A feature in some compilers where unreachable (dead) code is removed from the compiled output for performance and file-size reasons.
# 618  The big data software stack consisting of Spark, Mesos, Akka, Cassandra and Kafka
# 619  Zig is an open-source programming language designed for robustness, optimality, and clarity.
# 620  enclose is a node module which is used to compile the node js application.
# 621  For questions related to Data Flow Diagrams
# 622  codemod is a tool/library to assist you with large-scale codebase refactors that can be partially automated but still require human oversight and occasional intervention.
# 623  Tumblr's lightweight framework for building high-performance applications in Scala that require non-blocking network I/O.
# 624  Relationship Extraction is an IBM Watson Service that can analyze news articles and use statistical modeling to perform linguistic analysis(Name Entity Recognition) of the input text. It then finds spans of text and clusters them together to form entities, before finally extracting the relationships between them.\n
# 625  LoadLeveler is a job scheduler written by IBM, to control scheduling of batch jobs.\n
# 626  ECMAScript (or ES) is a scripting-language specification standardized by Ecma International in ECMA-262 and ISO/IEC 16262. It was created to standardize JavaScript, so as to foster multiple independent implementations. \n\nThe 9th edition, officially known as ECMAScript 2018, was finalized in June 2018. New features include rest/spread properties, asynchronous iteration, Promise.prototype.finally() and additions to RegExp
# 627  Apple's term for mixing Swift and Objective-C code in the same project. \n
# 628  Neptune is a machine learning lab by deepsense.ai. For Amazon Neptune, the fully managed graph database by AWS, use the tag "amazon-neptune".
# 629  Features related to running a command in a manner that merely previews its intended operation.
# 630  utility to help make Compose files more reusable and sharable.
# 631  CONNECT-REST - Exceptionally featureful Restful web services middleware for connect node.js

# %%
individual_tag_mapping = {matched_tag_types.TagName.values[i]: matched_tag_types.TagType.values[i] 
                          for i in range(matched_tag_types.shape[0])}
individual_tag_mapping.update({'google-cloud-firestore': 'cloud-database', 'google-cloud-functions': 'cloud-compute-solution', 'pyqt5': 'ui-api', 
                               'wxpython': 'ui-connector', 'retrtofit2': 'web-client', 'azure-functions': 'cloud-compute-solution', 'javamail': 'web-api', 
                               'wmi': 'os-api', 'azure-cosmosdb': 'cloud-database', 'antlr': 'compiler-framework', 'aws-api-gateway': 'cloud-api-solution', 
                               'vuex': 'framework-library', 'amazon-cognito': 'cloud-data-solution', 'asp.net-core-webapi': 'web-api', 'angular-material2': 'framework-library', 
                               'azure-service-fabric': 'cloud-dev-solution', 'angular2-forms': 'framework-concept', 'azure-pipelines': 'cloud-build-solution', 'vuetify.js': 'framework-framework', 
                               'ngrx': 'framework-library', 'nsis': 'build-solution', 'angular2-services': 'framework-concept', 'setuptools': 'build-library', 'roslyn': 'compiler-api', 'nuxt.js': 'framework-framework', 
                               'gcloud': 'admin-tool', 'emgucv': 'gfx-connector', 'dask': 'analytics-library', 'resttemplate': 'framework-feature', 'azure-application-insights': 'cloud-analytics-solution', 'caliburn.micro': 'mvc-framework', 
                               'react-hooks': 'framework-feature', 'amazon-sns': 'cloud-notif-service', 'spring-webflux': 'framework-feature', 'gatsby': 'framework-library', 'statsmodels': 'analytics-library', 
                               'image-segmentation': 'gfx-concept', 'glfw': 'gfx-library', 'firebase-analytics': 'cloud-analytics-solution', 'tensorboard': 'framework-library', 'next.js': 'framework-framework', 'redux-saga': 'framework-connector', 
                               'spacy': 'ml-library', 'code-formatting': 'design-concept', 'xgboost': 'ml-library', 'jacoco': 'test-tool', 'owl-carousel': 'framework-library', 'react-apollo': 'framework-ui-library', 'shapefile': 'map-format', 
                               'azure-powershell': 'cloud-admin-solution', 'kubectl': 'container-cmd-tool', 'apache-zeppelin': 'analytics-tool', 'azure-data-lake': 'cloud-analytics-solution', 'razor-pages': 'framework-feature', 'androidx': 'mobile-library', 
                               'android-camera2': 'mobile-library', 'unit-of-work': 'design-concept', 'keytool': 'security-tool', 'azure-iot-hub': 'cloud-connector-solution', 'apollo-client': 'ui-library', 'traefik': 'web-proxy', 'scikit-image': 'cv-library', 
                               'arcore':'ar-framework', 'amazon-athena': 'cloud-database-tool', 'rbenv': 'versioning-library', 'force-layout': 'ui-concept', 'gradle-plugin': 'solution-concept', 'minikube': 'container-vm-tool', 'glew': 'gfx-library', 'ionic-native': 'mobile-sdk', 
                               'informatica-powercenter': 'data-connector-solution', 'cpython': 'lang-implementation', 'azure-api-management': 'cloud-api-solution', 'react-native-navigation': 'framework-library', 'autosuggest': 'ui-concept', 'android-keystore': 'mobile-api', 
                               'virtuemart': 'commerce-solution', 'android-jetpack': 'mobile-sdk', 'sparkr': 'analytics-library', 'spring-cloud-config': 'server-solution', 'istio': 'microserv-solution', 'arm-template': 'cloud-solution-feature', 'vue-cli': 'admin-tool', 
                               'ambari': 'analytics-server-solution', 'actioncable': 'framework-library', 'aws-iot': 'cloud-connector-solution', 'ngrx-store': 'framework-library', 'azure-virtual-network': 'web-proxy', 'web3': 'blockchain-framework', 'ngx-bootstrap': 'framework-connector', 
                               'mgo': 'database-connector', 'image-compression': 'cv-concept', 'semantic-ui-react': 'framework-ui-library', 'firedac': 'connector-library', 'topojson': 'map-format', 'sinch': 'mobile-sdk', 'ngrx-effects': 'framework-library', 'node-sass': 'framework-connector', 
                               'hibernate-annotations': 'library-concept', 'angular-template': 'framework-concept', 'react-native-firebase': 'framework-library', 'kotlin-android-extensions': 'mobile-library', 'cntk': 'ml-library', 'powerapps': 'dev-solution', 
                               'tpl-dataflow': 'framework-library', 'react-router-redux': 'framework-library', 'web3js': 'blockchain-library', 'truffle':'blockchain-dev-solution', 'oidc': 'security-connector', 'aws-codebuild': 'cloud-dev-solution', 
                               'yolo': 'cv-library', 'azure-cognitive-services': 'cloud-ml-solution', 'uicontrol': 'mobile-framework-feature', 'mockmvc': 'mvc-framework-feature', 'amazon-lex': 'cloud-ml-solution', 'undertow': 'web-server-solution', 'windows-firewall': 'security-solution', 
                               'vmware-workstation': 'vm-solution', 'workbox': 'server-build-solution', 'replicaset': 'database-feature', 'laravel-dusk':'framework-test-api', 'azure-kubernetes': 'cloud-container-solution', 'azure-api-apps': 'cloud-api-solution', 'rpa': 'ml-concept', 
                               'changeset': 'versioning-concept', 'azure-container-service': 'cloud-container-solution', 'pwm': 'hardware-concept', 'rssi': 'comms-concept', 'react-context': 'framework-feature', 'holoviews': 'analytics-library', 'aot': 'management-platform-feature', 
                               'arcmap': 'map-tool', 'read-the-docs': 'wiki', 'prisma': 'database-connector', 'snort': 'network-security-tool', 'runtime-permissions': 'mobile-feature', 'fabric8': 'microserv-solution', 'qt3d': 'gfx-library', 'elastica': 'analytics-library', 'saga': 'design-concept', 
                               'background-subtraction': 'cv-concept', 'element-ui': 'framework-library', 'ack': 'compile-tool', 'bloc': 'design-concept', 'go-ethereum': 'blockchain-library', 'quantization': 'math-concept', 'swift-package-manager': 'build-solution', 'design-by-contract':'design-concept', 
                               'vbox': 'library-feature', 'geth': 'blockchain-library', 'seq2seq': 'ml-library', 'recompose': 'framework-library', 'monorepo': 'versioning-concept', 'color-mapping': 'ui-concept', 'elasticsearch-query': 'framework-concept', 'polly': 'framework-library', 
                               'visual-recognition': 'cv-solution', 'row-level-security': 'database-security-concept', 'free-monad': 'design-concept', 'vue-material': 'framework-framework', 'google-slides': 'cloud-collab-solution', 'volusion': 'web-commerce-solution', 'bounded-contexts': 'design-concept', 
                               'graphframes': 'analytics-library', 'metamask':'web-connector', 'dl4j': 'ml-library', 'natural-join': 'database-concept', 'amazon-quicksight': 'cloud-analytics-solution', 'specification-pattern': 'design-concept', 'statechart': 'design-concept', 'pprof':'server-library', 'sku': 'business-concept', 
                               'deform': 'web-library', 'mapping-model': 'design-concept', 'reportng': 'framework-tool', 'srv':'tech-concept', 'blue-green-deployment': 'deployment-concept', 'symfony-flex': 'admin-tool', 'sld': 'map-format', 'adaptive-ui': 'mobile-ui', 'flowable':'business-library', 'seneca':'microserv-library', 
                               'private-subnet':'network-concept', 'highrise': 'management-solution', 'cucm': 'business-tool', 'image-viewer': 'gfx-tool', 'hapi.js': 'framework-server-framework', 'rook': 'web-library', 'radium': 'framework-library', 'canary-deployment': 'deployment-concept', 'pbr': 'gfx-concept', 
                               'jquery-ui-plugins': 'framework-ui-concept', 'contract-first': 'design-concept', 'ispf': 'admin-tool', 'react-fiber': 'framework-library', 'no-framework': 'design-concept', '.net-core-1.1': 'web-framework', 'data-access-object': 'design-concept', 'pallet': 'deployment-solution', 'automatic-failover': 'database-concept', 
                               'slab': 'framework-feature', 'manifold': 'map-tool', 'account-linking':'database-concept', 'floating-ip': 'network-concept', 'geopackage': 'map-format', 'map-basic': 'map-language', 'connection-points': 'connector-concept', 'staging-table': 'data-concept', 'reaper': 'audio-tool', 'zen-of-python': 'design-concept',
                               'koa.js': 'connector-framework', 'authentication-flows':'framework-security-framework', 'hibernate-query': 'database-language', 'prototype-scope': 'framework-concept', 'management-pack': 'admin-tool', 'haxl':'connector-library', 'code-elimination': 'compile-concept', 'enclose': 'framework-compile-library', 
                               'dfd':'design-concept', 'codemod': 'compile-tool', 'loadleveler': 'tool', 'mix-and-match': 'lang-concept', 'connect-rest': 'framework-connector'})
matched_tag_types['TagTypeRevised'] = matched_tag_types.TagName.apply(lambda x: individual_tag_mapping[x])

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', -1):
    display(pd.merge(matched_tag_types, merged_both_after_warmup[['TagName', 'Excerpt']], on='TagName'))
# Out:
#                             TagName              TagType IsVersion  \
# 0    vuejs2                          web-framework        True
# 1    google-cloud-firestore          database             False
# 2    json.net                        web-framework        False
# 3    ionic3                          mobile-sdk           True
# 4    mongodb-query                   lang-concept         False
# 5    firebase-cloud-messaging        cloud-solution       False
# 6    pthreads                        api                  False
# 7    java-stream                     lang-feature         False
# 8    google-cloud-functions          cloud-solution       False
# 9    axios                           web-library          False
# 10   google-cloud-datastore          cloud-database       False
# 11   angular5                        web-framework        True
# 12   linq-to-entities                lang-feature         False
# 13   pyqt5                           api                  True
# 14   wxpython                        connector            False
# 15   retrofit2                       framework            True
# 16   vue-component                   lang-feature         False
# 17   azure-functions                 cloud-solution       False
# 18   automapper                      library              False
# 19   maven-3                         build-solution       True
# 20   hql                             language             False
# 21   racket                          language             False
# 22   javamail                        api                  False
# 23   python-3.6                      language             True
# 24   laravel-5.3                     web-framework        True
# 25   laravel-5.4                     web-framework        True
# 26   pymongo                         database-connector   False
# 27   c++17                           language             True
# 28   hyperledger-fabric              blockchain-solution  False
# 29   wmi                             api                  False
# 30   static-libraries                tech-concept         False
# 31   typeerror                       tech-concept         False
# 32   pytorch                         ml-framework         False
# 33   react-navigation                lang-feature         False
# 34   azure-cosmosdb                  database-solution    False
# 35   unity-container                 lang-feature         False
# 36   raspberry-pi3                   hardware             True
# 37   antlr                           framework            False
# 38   aws-api-gateway                 cloud-solution       False
# 39   lstm                            ml-concept           False
# 40   vuex                            library              False
# 41   boto3                           cloud-sdk            True
# 42   amazon-cognito                  cloud-solution       False
# 43   ionic4                          mobile-sdk           True
# 44   httpurlconnection               tech-concept         False
# 45   asp.net-core-webapi             api                  False
# 46   angular-material2               library              True
# 47   symfony4                        web-framework        True
# 48   azure-service-fabric            cloud-solution       False
# 49   postback                        tech-concept         False
# 50   laravel-5.5                     web-framework        True
# 51   angular2-forms                  lang-concept         False
# 52   azure-pipelines                 cloud-solution       False
# 53   tidyverse                       library              False
# 54   vuetify.js                      web-framework        False
# 55   ngrx                            library              False
# 56   nsis                            software-solution    False
# 57   angular2-services               lang-feature         False
# 58   xlsx                            file-format          False
# 59   keycloak                        security-framework   False
# 60   arkit                           ar-framework         False
# 61   setuptools                      library              False
# 62   roslyn                          api                  False
# 63   nuxt.js                         web-framework        False
# 64   compiler-warnings               tech-concept         False
# 65   gcloud                          lang-feature         False
# 66   okhttp                          web-client           False
# 67   soap-client                     web-client           False
# 68   emgucv                          connector            False
# 69   gremlin                         language             False
# 70   barcode-scanner                 hardware             False
# 71   iis-express                     server-solution      False
# 72   dask                            library              False
# 73   typescript-typings              lang-feature         False
# 74   resttemplate                    lang-feature         False
# 75   laravel-5.6                     web-framework        False
# 76   paramiko                        security-library     False
# 77   python-3.7                      language             True
# 78   azure-application-insights      analytics-solution   False
# 79   tidyr                           library              False
# 80   caliburn.micro                  app-framework        False
# 81   indexeddb                       lang-feature         False
# 82   react-hooks                     lang-feature         False
# 83   powermock                       library              False
# 84   amazon-sns                      cloud-solution       False
# 85   bean-validation                 framework            False
# 86   spring-webflux                  library              False
# 87   guzzle                          web-client           NaN
# 88   elf                             file-format          False
# 89   gatsby                          library              False
# 90   sha1                            security-concept     False
# 91   statsmodels                     library              False
# 92   slack-api                       api                  False
# 93   word2vec                        ml-concept           False
# 94   poco                            tech-concept         False
# 95   lex                             compiler-solution    False
# 96   image-segmentation              tech-concept         False
# 97   scala-collections               library              False
# 98   webpack-2                       build-solution       True
# 99   static-linking                  tech-concept         False
# 100  node-red                        connector            False
# 101  ini                             file-format          False
# 102  glfw                            library              False
# 103  firebase-analytics              cloud-solution       False
# 104  tensorboard                     library              False
# 105  next.js                         web-framework        False
# 106  redux-saga                      connector            False
# 107  spacy                           library              False
# 108  code-formatting                 tech-concept         False
# 109  xgboost                         library              False
# 110  jacoco                          build-solution       False
# 111  large-files                     tech-concept         False
# 112  gnupg                           security-framework   False
# 113  owl-carousel                    library              False
# 114  react-apollo                    library              False
# 115  shapefile                       format               False
# 116  azure-powershell                admin-solution       False
# 117  knex.js                         database-framework   False
# 118  chef-recipe                     lang-feature         False
# 119  netcdf                          standard             False
# 120  kubectl                         admin-solution       False
# 121  apache-zeppelin                 analytics-solution   False
# 122  private-key                     security-concept     False
# 123  android-livedata                library              False
# 124  p5.js                           library              False
# 125  cache-control                   tech-concept         False
# 126  server-sent-events              tech-concept         False
# 127  lubridate                       library              False
# 128  azure-data-lake                 cloud-solution       False
# 129  rubymine                        ide                  False
# 130  key-value-observing             tech-concept         False
# 131  cpan                            wiki                 False
# 132  androidx                        library              False
# 133  ode                             math-concept         False
# 134  gnome                           ui                   False
# 135  lattice                         library              False
# 136  razor-pages                     lang-feature         NaN
# 137  android-camera2                 library              True
# 138  unit-of-work                    tech-concept         False
# 139  keytool                         library              False
# 140  webpack-4                       build-solution       False
# 141  azure-iot-hub                   cloud-solution       False
# 142  hmac                            security-concept     False
# 143  apollo-client                   library              False
# 144  traefik                         connector            False
# 145  autofill                        tech-concept         False
# 146  scikit-image                    library              False
# 147  arcore                          framework            False
# 148  epoch                           tech-concept         False
# 149  junit5                          test-framework       True
# 150  amazon-athena                   cloud-solution       False
# 151  httpserver                      tech-concept         False
# 152  visual-studio-2019              ide                  True
# 153  rbenv                           library              False
# 154  rdp                             standard             False
# 155  diacritics                      tech-concept         False
# 156  jsonpath                        lang-concept         False
# 157  gradient-descent                math-concept         False
# 158  force-layout                    lang-concept         False
# 159  mcrypt                          security-library     False
# 160  gradle-plugin                   build-solution       False
# 161  minikube                        server-solution      False
# 162  java-11                         language             True
# 163  glew                            library              False
# 164  ionic-native                    framework            False
# 165  csproj                          file-format          False
# 166  sas-macro                       meta-language        False
# 167  informatica-powercenter         data-solution        False
# 168  cpython                         library              False
# 169  azure-api-management            cloud-solution       False
# 170  access-denied                   tech-concept         False
# 171  react-native-navigation         library              False
# 172  google-cloud-ml                 ml-cloud-solution    False
# 173  tfs2017                         dev-solution         False
# 174  avx                             language             False
# 175  autoencoder                     ml-concept           False
# 176  dlib                            library              False
# 177  keep-alive                      tech-concept         False
# 178  tslint                          lang-feature         False
# 179  ramda.js                        library              False
# 180  autosuggest                     tech-concept         False
# 181  android-keystore                lang-feature         False
# 182  virtuemart                      software-solution    False
# 183  android-jetpack                 library              False
# 184  apollo-server                   server-solution      False
# 185  neon                            language             False
# 186  sparkr                          library              False
# 187  spring-cloud-config             cloud-solution       False
# 188  istio                           management-solution  False
# 189  opensuse                        os                   False
# 190  arm-template                    lang-feature         False
# 191  vue-cli                         lang-feature         False
# 192  serial-communication            tech-concept         False
# 193  openshift-origin                container-solution   False
# 194  ambari                          management-solution  False
# 195  docker-for-windows              container-solution   False
# 196  iphone-x                        hardware             True
# 197  actioncable                     library              False
# 198  aws-iot                         connector            False
# 199  ngrx-store                      library              False
# 200  azure-virtual-network           network-solution     False
# 201  azure-machine-learning-studio   ml-solution          False
# 202  web3                            web-framework        False
# 203  google-sites                    web-solution         False
# 204  monad-transformers              tech-concept         False
# 205  ngx-bootstrap                   connector            False
# 206  mgo                             connector            False
# 207  azure-stream-analytics          analytics-solution   False
# 208  postgresql-9.6                  database             True
# 209  image-compression               tech-concept         False
# 210  dynamics-365                    management-solution  False
# 211  php-7.2                         language             True
# 212  laravel-mix                     web-api              False
# 213  semantic-ui-react               library              False
# 214  http-authentication             tech-concept         False
# 215  google-play-console             admin-tool           False
# 216  grid-search                     ml-concept           False
# 217  cucumber-java                   collab-solution      False
# 218  amazon-sagemaker                ml-solution          False
# 219  data-fitting                    math-concept         False
# 220  firedac                         library              False
# 221  topojson                        format               False
# 222  sinch                           sdk                  False
# 223  specs2                          library              False
# 224  ngrx-effects                    library              False
# 225  mxnet                           ml-framework         False
# 226  automata                        math-concept         False
# 227  aidl                            language             False
# 228  eigenvalue                      math-concept         False
# 229  node-sass                       connector            False
# 230  hibernate-annotations           lang-feature         False
# 231  unix-socket                     connector            False
# 232  angular-template                lang-feature         False
# 233  rvalue                          tech-concept         False
# 234  react-native-firebase           library              False
# 235  kotlin-android-extensions       library              False
# 236  cntk                            library              False
# 237  netlify                         deployment-solution  False
# 238  powerapps                       software-solution    False
# 239  tpl-dataflow                    library              False
# 240  react-router-redux              library              False
# 241  kotlin-coroutines               library              False
# 242  web-push                        web-api              False
# 243  numerical-integration           math-concept         False
# 244  coreml                          ml-framework         False
# 245  bulma                           web-framework        False
# 246  web3js                          library              False
# 247  functional-dependencies         tech-concept         False
# 248  truffle                         dev-solution         False
# 249  tensorflow.js                   ml-library           False
# 250  azure-automation                management-solution  False
# 251  netstat                         admin-tool           False
# 252  mapstruct                       lang-feature         False
# 253  oidc                            connector            False
# 254  managed-c++                     deprecated-standard  False
# 255  ansible-inventory               solution-feature     False
# 256  google-vr                       vr-framework         False
# 257  apostrophe                      tech-concept         False
# 258  richtext                        tech-concept         False
# 259  error-code                      tech-concept         False
# 260  aws-codebuild                   software-solution    False
# 261  yolo                            library              False
# 262  powershell-ise                  ide                  False
# 263  zoho                            company              False
# 264  azure-cognitive-services        ml-solution          False
# 265  django-2.0                      web-framework        True
# 266  ngrok                           web-proxy            False
# 267  partial-classes                 tech-concept         False
# 268  uicontrol                       framework-feature    False
# 269  mockmvc                         framework-feature    False
# 270  frameset                        lang-feature         False
# 271  amazon-lex                      ml-solution          False
# 272  undertow                        server-solution      False
# 273  memory-barriers                 tech-concept         False
# 274  net-http                        web-api              False
# 275  c#-7.0                          language             True
# 276  joi                             lang-feature         False
# 277  p-value                         math-concept         False
# 278  watchdog                        tech-concept         False
# 279  fixed-point                     tech-concept         False
# 280  pundit                          library              False
# 281  opcode                          tech-concept         False
# 282  windows-firewall                security-software    False
# 283  android-instrumentation         lang-feature         False
# 284  vmware-workstation              vm-software          False
# 285  workbox                         server-solution      False
# 286  algebraic-data-types            tech-concept         False
# 287  web-api-testing                 tech-concept         False
# 288  surveymonkey                    survey-service       False
# 289  replicaset                      lang-concept         False
# 290  java-module                     lang-feature         False
# 291  superagent                      web-api              False
# 292  save-as                         tech-concept         False
# 293  secret-key                      security-concept     False
# 294  .net-core-2.0                   web-framework        True
# 295  php4                            language             True
# 296  aws-serverless                  cloud-solution       False
# 297  laravel-dusk                    test-api             False
# 298  azure-kubernetes                container-solution   False
# 299  azure-api-apps                  cloud-solution       False
# 300  tfs2018                         dev-solution         True
# 301  orc                             format               False
# 302  pwm                             tech-concept         False
# 303  rpa                             tech-concept         False
# 304  changeset                       tech-concept         False
# 305  firebase-cli                    admin-tool           False
# 306  swift5                          language             True
# 307  wit.ai                          ml-solution          False
# 308  django-1.11                     web-framework        True
# 309  azure-container-service         container-solution   False
# 310  wavelet                         math-concept         False
# 311  mern                            dev-solution         False
# 312  rssi                            tech-concept         False
# 313  inode                           tech-concept         False
# 314  react-context                   lang-feature         False
# 315  holoviews                       library              False
# 316  ecmascript-2017                 language             True
# 317  aot                             lang-feature         False
# 318  arcmap                          software-tool        False
# 319  maven-failsafe-plugin           framework-feature    False
# 320  read-the-docs                   collab-solution      False
# 321  django-2.1                      web-framework        True
# 322  sightly                         language             False
# 323  np-complete                     math-concept         False
# 324  prisma                          connector            False
# 325  snort                           security-tool        False
# 326  heroku-cli                      admin-tool           False
# 327  geotiff                         standard             False
# 328  hyperparameters                 ml-concept           False
# 329  http-response-codes             tech-concept         False
# 330  css-variables                   lang-concept         False
# 331  browser-plugin                  web-tool             False
# 332  jigsaw                          framework            False
# 333  runtime-permissions             lang-feature         False
# 334  aws-codecommit                  versioning-solution  False
# 335  fabric8                         management-solution  False
# 336  qt3d                            library              False
# 337  dot-product                     math-concept         False
# 338  multinomial                     math-concept         False
# 339  zipkin                          server-tool          False
# 340  dbeaver                         database-tool        False
# 341  windows-10-desktop              ui                   False
# 342  elastica                        library              False
# 343  saga                            tech-concept         False
# 344  background-subtraction          tech-concept         False
# 345  element-ui                      library              False
# 346  kotlin-extension                lang-concept         False
# 347  dotnet-cli                      admin-tool           False
# 348  ack                             software-tool        False
# 349  c++-concepts                    language             True
# 350  ipfs                            standard             False
# 351  batch-normalization             ml-concept           False
# 352  mixed-content                   tech-concept         False
# 353  spatial-index                   tech-concept         False
# 354  jenkins-slave                   framework-concept    False
# 355  reactive-forms                  framework-concept    False
# 356  bloc                            tech-concept         False
# 357  go-ethereum                     library              False
# 358  eiffel                          language             False
# 359  quantization                    tech-concept         False
# 360  splitter                        tech-concept         False
# 361  otrs                            management-solution  False
# 362  msg                             file-format          False
# 363  mle                             ml-concept           False
# 364  swift-package-manager           build-tool           False
# 365  data-partitioning               tech-concept         False
# 366  docker-swarm-mode               framework-feature    False
# 367  cryptocurrency                  security-concept     False
# 368  centroid                        math-concept         False
# 369  design-by-contract              tech-concept         False
# 370  eeprom                          hardware             False
# 371  scss-mixins                     lang-feature         False
# 372  vbox                            lang-feature         False
# 373  lottie                          library              False
# 374  nano                            ide                  False
# 375  serde                           framework            False
# 376  bacon.js                        library              False
# 377  directory-listing               tech-concept         False
# 378  generative-adversarial-network  ml-concept           False
# 379  django-1.10                     web-framework        True
# 380  image-caching                   tech-concept         False
# 381  geth                            library              False
# 382  kvc                             tech-concept         False
# 383  seq2seq                         library              False
# 384  reentrancy                      tech-concept         False
# 385  recompose                       library              False
# 386  blazemeter                      test-solution        False
# 387  ftp-server                      tech-concept         False
# 388  ico                             file-format          False
# 389  fasttext                        ml-library           False
# 390  mongodb-replica-set             lang-feature         False
# 391  watson-assistant                ml-solution          False
# 392  servo                           hardware-concept     False
# 393  non-deterministic               math-concept         False
# 394  webpack-3                       build-tool           True
# 395  kestrel                         library              False
# 396  m4                              language             False
# 397  html-validation                 tech-concept         False
# 398  jwt-auth                        standard             False
# 399  monorepo                        tech-concept         False
# 400  color-mapping                   tech-concept         False
# 401  mixture-model                   ml-concept           False
# 402  elasticsearch-query             lang-concept         False
# 403  circle-pack                     math-concept         False
# 404  ff                              library              False
# 405  persistent-volumes              framework-feature    False
# 406  forex                           commerce-concept     False
# 407  session-scope                   lang-concept         False
# 408  aws-sam                         cloud-framework      False
# 409  readxl                          library              False
# 410  opencv-python                   deprecated-library   False
# 411  cloudify                        cloud-solution       False
# 412  pushdown-automaton              math-concept         False
# 413  polly                           library              False
# 414  typescript3.0                   language             True
# 415  daydream                        vr-solution          False
# 416  catkin                          build-solution       False
# 417  visual-recognition              ml-solution          False
# 418  redux-framework                 web-framework        False
# 419  random-walk                     math-concept         False
# 420  row-level-security              tech-concept         False
# 421  facebook-analytics              analytics-solution   False
# 422  azure-container-registry        framework-feature    False
# 423  free-monad                      tech-concept         False
# 424  bpf                             network-connector    False
# 425  jcache                          api                  False
# 426  powershell-core                 admin-tool           False
# 427  unreal-blueprint                lang-feature         False
# 428  stack-memory                    tech-concept         False
# 429  vue-material                    web-framework        False
# 430  google-slides                   cloud-tool           False
# 431  angular-elements                framework-feature    False
# 432  volusion                        commerce-solution    False
# 433  orthogonal                      math-concept         False
# 434  bounded-contexts                tech-concept         False
# 435  angular-testing                 lang-concept         False
# 436  conditional-breakpoint          tech-concept         False
# 437  pwd                             cmd-tool             False
# 438  graphframes                     library              False
# 439  tailwind-css                    web-framework        False
# 440  s-expression                    tech-concept         False
# 441  metamask                        web-tool             False
# 442  wp-cli                          admin-tool           False
# 443  app-startup                     tech-concept         False
# 444  dl4j                            library              False
# 445  pisa                            library              False
# 446  run-configuration               tech-concept         False
# 447  natural-join                    tech-concept         False
# 448  backpressure                    tech-concept         False
# 449  react-360                       vr-framework         False
# 450  google-vr-sdk                   vr-sdk               False
# 451  django-deployment               framework-concept    False
# 452  launchpad                       collab-solution      False
# 453  dropout                         ml-concept           False
# 454  deap                            compute-framework    False
# 455  amazon-quicksight               analytics-solution   False
# 456  auto-value                      lang-feature         False
# 457  cross-language                  tech-concept         False
# 458  watson-studio                   ml-solution          False
# 459  feature-descriptor              ml-concept           False
# 460  zeus                            library              False
# 461  khan-academy                    edu-platform         False
# 462  facebook-instant-games          game-platform        False
# 463  fabric.io                       mobile-framework     False
# 464  aws-ebs                         framework-feature    False
# 465  face-id                         ml-solution          False
# 466  binance                         deprecated-api       False
# 467  java-ee-8                       language             True
# 468  htop                            cmd-tool             False
# 469  specification-pattern           tech-concept         False
# 470  action-mapping                  lang-feature         False
# 471  statechart                      tech-concept         False
# 472  varray                          lang-feature         False
# 473  spectron                        test-framework       False
# 474  python-regex                    library              False
# 475  configmap                       lang-feature         False
# 476  adobe-animate                   gfx-tool             False
# 477  kitura                          server-framework     False
# 478  mpd                             audio-tool           False
# 479  redis-server                    database             False
# 480  pprof                           library              False
# 481  sku                             tech-concept         False
# 482  airtable                        database             False
# 483  model-comparison                ml-concept           False
# 484  subject-observer                tech-concept         False
# 485  deform                          library              False
# 486  python-typing                   lang-concept         False
# 487  android-device-monitor          ui-tool              False
# 488  authenticity-token              lang-feature         False
# 489  knuth                           person               False
# 490  tmpfs                           tech-concept         False
# 491  openvino                        ml-solution          False
# 492  microprofile                    microserv-framework  False
# 493  ucp                             network-library      False
# 494  archer                          dev-solution         False
# 495  idoc                            language             False
# 496  mapping-model                   tech-concept         False
# 497  snowball                        language             False
# 498  referential-transparency        tech-concept         False
# 499  dyno                            container-solution   False
# 500  kolmogorov-smirnov              math-concept         False
# 501  reportng                        library              False
# 502  aws-codestar                    cloud-solution       False
# 503  alv                             library              False
# 504  steamvr                         vr-game-platform     False
# 505  srv                             framework-feature    False
# 506  blue-green-deployment           tech-concept         False
# 507  cert-manager                    admin-solution       False
# 508  docker-engine                   container-solution   False
# 509  symfony-flex                    library              False
# 510  openvas                         security-framework   False
# 511  unit-type                       tech-concept         False
# 512  sld                             format               False
# 513  calico                          compute-framework    False
# 514  ether                           commerce-concept     False
# 515  adaptive-ui                     library              False
# 516  html-object                     lang-concept         False
# 517  chefdk                          sdk                  False
# 518  spring-io                       framework            False
# 519  pathauto                        library              False
# 520  graphql-tools                   library              False
# 521  flowable                        library              False
# 522  seneca                          library              False
# 523  private-subnet                  tech-concept         False
# 524  sling-models                    lang-concept         False
# 525  torii                           lang-feature         False
# 526  siege                           web-tool             False
# 527  highrise                        management-tool      False
# 528  mlp                             ml-concept           False
# 529  quora                           website              False
# 530  shaderlab                       language             False
# 531  cucm                            commerce-tool        False
# 532  createml                        ml-solution          False
# 533  wagon                           framework-feature    False
# 534  cold-start                      tech-concept         False
# 535  tether                          library              False
# 536  windows-server-2019             os                   True
# 537  image-viewer                    app                  False
# 538  hapi.js                         web-framework        False
# 539  raw-pointer                     tech-concept         False
# 540  ddl-trigger                     lang-concept         False
# 541  rook                            library              False
# 542  pvcs                            dev-solution         False
# 543  upx                             compression-tool     False
# 544  android-make                    lang-concept         False
# 545  decentralized-applications      tech-concept         False
# 546  radium                          library              False
# 547  canary-deployment               tech-concept         False
# 548  n3                              language             False
# 549  rcu                             tech-concept         False
# 550  pbr                             tech-concept         False
# 551  react-fullstack                 web-framework        False
# 552  nameko                          microserv-framework  False
# 553  jquery-ui-plugins               framework-feature    False
# 554  contract-first                  tech-concept         False
# 555  azure-stack                     cloud-solution       False
# 556  ispf                            management-tool      False
# 557  elasticsearch-api               lang-concept         False
# 558  unfold                          tech-concept         False
# 559  kurtosis                        math-concept         False
# 560  configuration-profile           config-format        False
# 561  insomnia                        web-client           False
# 562  react-fiber                     library              False
# 563  apex-trigger                    lang-concept         False
# 564  fiddle                          library              False
# 565  no-framework                    tech-concept         False
# 566  .net-core-1.1                   framework            True
# 567  data-access-object              tech-concept         False
# 568  reify                           tech-concept         False
# 569  p-np                            math-concept         False
# 570  pallet                          framework            False
# 571  crdt                            data-format          False
# 572  multi-catch                     lang-feature         False
# 573  automatic-failover              tech-concept         False
# 574  chgrp                           cmd-tool             False
# 575  slab                            lang-feature         False
# 576  mirage                          framework            False
# 577  git-track                       versioning-concept   False
# 578  manifold                        software-tool        False
# 579  aws-storage-gateway             cloud-connector      False
# 580  version-compatibility           tech-concept         False
# 581  account-linking                 tech-concept         False
# 582  chirp                           hardware-concept     False
# 583  message-channel                 framework-feature    False
# 584  fmt                             library              False
# 585  cactus                          test-framework       False
# 586  neutrino                        dev-tool             False
# 587  ecmascript-2016                 language             True
# 588  oracle-analytics                lang-concept         False
# 589  treeline                        web-framework        False
# 590  jakarta-ee                      dev-solution         False
# 591  docker-ee                       container-solution   False
# 592  floating-ip                     tech-concept         False
# 593  dtr                             framework-feature    False
# 594  geopackage                      format               False
# 595  argon                           web-client           False
# 596  spring-modules                  lang-concept         False
# 597  map-basic                       language             False
# 598  rls                             ide                  False
# 599  option-type                     lang-feature         False
# 600  list-processing                 tech-concept         False
# 601  connection-points               framework-feature    False
# 602  staging-table                   tech-concept         False
# 603  access-protection               tech-concept         False
# 604  reaper                          software-tool        False
# 605  zen-of-python                   tech-concept         False
# 606  npn                             standard             False
# 607  sysdig                          admin-tool           False
# 608  tia-portal                      admin-tool           False
# 609  koa.js                          framework            False
# 610  astro                           admin-tool           False
# 611  authentication-flows            security-framework   False
# 612  hibernate-query                 language             False
# 613  prototype-scope                 lang-concept         False
# 614  management-pack                 management-tool      False
# 615  haxl                            library              False
# 616  poet                            web-framework        False
# 617  code-elimination                tech-concept         False
# 618  smack-stack                     framework            False
# 619  zig                             language             False
# 620  enclose                         library              False
# 621  dfd                             tech-concept         False
# 622  codemod                         library              False
# 623  colossus                        framework            False
# 624  relationship-extraction         ml-tool              False
# 625  loadleveler                     library              False
# 626  es2018                          language             True
# 627  mix-and-match                   tech-concept         False
# 628  neptune                         ml-solution          False
# 629  dry-run                         tech-concept         False
# 630  docker-app                      container-tool       False
# 631  connect-rest                    connector            False
#
#     IsMajorVersion                TagTypeRevised  \
# 0    True           web-framework
# 1    False          cloud-database
# 2    False          web-framework
# 3    True           mobile-sdk
# 4    False          lang-concept
# 5    False          cloud-solution
# 6    False          api
# 7    False          lang-feature
# 8    False          cloud-compute-solution
# 9    False          web-library
# 10   False          cloud-database
# 11   True           web-framework
# 12   False          lang-feature
# 13   True           ui-api
# 14   False          ui-connector
# 15   True           framework
# 16   False          lang-feature
# 17   False          cloud-compute-solution
# 18   False          library
# 19   True           build-solution
# 20   False          language
# 21   False          language
# 22   False          web-api
# 23   False          language
# 24   False          web-framework
# 25   False          web-framework
# 26   False          database-connector
# 27   True           language
# 28   False          blockchain-solution
# 29   False          os-api
# 30   False          tech-concept
# 31   False          tech-concept
# 32   False          ml-framework
# 33   False          lang-feature
# 34   False          cloud-database
# 35   False          lang-feature
# 36   True           hardware
# 37   False          compiler-framework
# 38   False          cloud-api-solution
# 39   False          ml-concept
# 40   False          framework-library
# 41   True           cloud-sdk
# 42   False          cloud-data-solution
# 43   True           mobile-sdk
# 44   False          tech-concept
# 45   False          web-api
# 46   True           framework-library
# 47   True           web-framework
# 48   False          cloud-dev-solution
# 49   False          tech-concept
# 50   False          web-framework
# 51   False          framework-concept
# 52   False          cloud-build-solution
# 53   False          library
# 54   False          framework-framework
# 55   False          framework-library
# 56   False          build-solution
# 57   False          framework-concept
# 58   False          file-format
# 59   False          security-framework
# 60   False          ar-framework
# 61   False          build-library
# 62   False          compiler-api
# 63   False          framework-framework
# 64   False          tech-concept
# 65   False          admin-tool
# 66   False          web-client
# 67   False          web-client
# 68   False          gfx-connector
# ...
# 598  The Rust Language Server (RLS) provides useful functionalities to IDEs, editors and other tools for Rust development, including code completion, 'goto definition', symbol search and reformatting.
# 599  The option type in F# is used when an actual value might not exist for a named value or variable. An option has an underlying type and can hold a value of that type, or it might not have a value.
# 600  List processing is a concept in many data-oriented languages that involves performing an action once for each member of a list.
# 601  Connection points are the standard COM interface exposed by connectable objects, that allows clients to register for event callbacks. This tag is for questions about implementing and registering clients with the IConnectionPoint interface.
# 602  Staging tables are used in data ETL (extraction transformation and loading) processes and data warehousing.
# 603  Restrictions that allow to protect variables from external/ unintended modification.
# 604  REAPER is digital audio workstation software: a complete multitrack audio and MIDI recording, editing, processing, mixing, and mastering environment.
# 605  Related to python best practices. A set of guiding principles for Python's code design comprising 20 aphorisms, only 19 of which have been written down; Created by Tim Peters.
# 606  The Next Protocol Negotiation extension (NPN) is currently used to negotiate the use of SPDY as an application level protocol.
# 607  Linux system exploration and troubleshooting tool with first class support for containers.
# 608  The TIA-Portal tag describes the SIMATIC STEP 7 Totally Integrated Automation Portal and is the graphical user interface for the broad range of Siemens PLCs. On this platform you can plan, program, validate, diagnose and control your written PLC program. The device database gives access to basic, advanced and distributed controllers of each generation.
# 609  A Koa application is an object containing an array of middleware generator functions which are composed and executed in a stack-like manner upon request
# 610  Some sort of file manager for android
# 611  Authentication-Flows is a powerful and highly customizable framework that covers all flows that authentication-server that is based on Spring-Security needs.
# 612  The Hibernate Query Language
# 613  A Spring specific scope used to define a Bean that will get newly created on each request.
# 614  SCOM (System Center Operation Manager) management packs. Management packs typically contain monitoring settings for applications and services. After a management pack is imported into a management group, System Center 2012 – Operations Manager immediately begins monitoring objects based on default configurations and thresholds that are set by the management pack.
# 615  Haxl is a Haskell library that simplifies access to remote data, such as databases or web-based services.
# 616  for questions about Poet, a web framework for Mason
# 617  A feature in some compilers where unreachable (dead) code is removed from the compiled output for performance and file-size reasons.
# 618  The big data software stack consisting of Spark, Mesos, Akka, Cassandra and Kafka
# 619  Zig is an open-source programming language designed for robustness, optimality, and clarity.
# 620  enclose is a node module which is used to compile the node js application.
# 621  For questions related to Data Flow Diagrams
# 622  codemod is a tool/library to assist you with large-scale codebase refactors that can be partially automated but still require human oversight and occasional intervention.
# 623  Tumblr's lightweight framework for building high-performance applications in Scala that require non-blocking network I/O.
# 624  Relationship Extraction is an IBM Watson Service that can analyze news articles and use statistical modeling to perform linguistic analysis(Name Entity Recognition) of the input text. It then finds spans of text and clusters them together to form entities, before finally extracting the relationships between them.\n
# 625  LoadLeveler is a job scheduler written by IBM, to control scheduling of batch jobs.\n
# 626  ECMAScript (or ES) is a scripting-language specification standardized by Ecma International in ECMA-262 and ISO/IEC 16262. It was created to standardize JavaScript, so as to foster multiple independent implementations. \n\nThe 9th edition, officially known as ECMAScript 2018, was finalized in June 2018. New features include rest/spread properties, asynchronous iteration, Promise.prototype.finally() and additions to RegExp
# 627  Apple's term for mixing Swift and Objective-C code in the same project. \n
# 628  Neptune is a machine learning lab by deepsense.ai. For Amazon Neptune, the fully managed graph database by AWS, use the tag "amazon-neptune".
# 629  Features related to running a command in a manner that merely previews its intended operation.
# 630  utility to help make Compose files more reusable and sharable.
# 631  CONNECT-REST - Exceptionally featureful Restful web services middleware for connect node.js
