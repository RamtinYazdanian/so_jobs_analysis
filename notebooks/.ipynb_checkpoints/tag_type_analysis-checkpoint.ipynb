# %%
from matplotlib import pyplot as plt
import numpy as np
import pickle
import pandas as pd
import os
import json
import seaborn as sns
from itertools import chain
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from collections import Counter
from datetime import datetime, timedelta
import operator
import sys
from bisect import bisect_right, bisect, bisect_left
from scipy.stats import chisquare
sys.path.insert(0, '../')
from utilities.analysis_tools import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
merged_both_after_warmup = pickle.load(open('matched_tags_dataframe.pkl', 'rb'))
matched_tag_types = pd.read_csv('/home/yazdania/so_jobs_analysis/tags_to_categorise.csv', index_col=0)

# %%
so_tag_index = json.load(open('/dlabdata1/yazdania/trends_udemy/tag_to_index.json', 'r'))
so_week_index = pickle.load(open('/dlabdata1/yazdania/trends_udemy/tag_time_series_longer/week_index.pkl','rb'))
so_timeseries = pickle.load(open('/dlabdata1/yazdania/trends_udemy/tag_time_series_longer/tag_timeseries_matrix.pkl','rb'))

# %%
so_only_all = load_stack_overflow_trends(merged_both_after_warmup.TagName.values, 
                                               so_tag_index, so_week_index, so_timeseries,
                                                normalise = False)

# %%
adoption_sequences = calculate_all_adoption_sequences(merged_both_after_warmup, so_only_all)

# %%
all_tags = merged_both_after_warmup.TagName.values
tags_created_after_warmup = merged_both_after_warmup.loc[
            merged_both_after_warmup.TagFirstUseDate >= datetime(2016,10,1)].TagName.values
tags_from_one_year_before_warmup = merged_both_after_warmup.loc[
            merged_both_after_warmup.TagFirstUseDate >= datetime(2015,10,1)].TagName.values
tags_from_two_years_before_warmup = merged_both_after_warmup.loc[
            merged_both_after_warmup.TagFirstUseDate >= datetime(2014,10,1)].TagName.values
tags_popular = merged_both_after_warmup.loc[merged_both_after_warmup.TagCount > 
                                            merged_both_after_warmup.TagCount.median()].TagName.values

# %%
get_all_proportions(get_subset_of_tags(adoption_sequences, tags_created_after_warmup), 'short_adoption_seq')
# Out:
# (0.6106194690265486, 0.1504424778761062, 0.23893805309734514, 113)

# %%
get_all_proportions(get_subset_of_tags(adoption_sequences, tags_from_one_year_before_warmup), 'short_adoption_seq')
# Out:
# (0.7743589743589744, 0.08717948717948718, 0.13846153846153847, 195)

# %%
get_all_proportions(get_subset_of_tags(adoption_sequences, tags_popular), 'short_adoption_seq')
# Out:
# (0.9746031746031746, 0.0031746031746031746, 0.022222222222222223, 315)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', -1):
    display(matched_tag_types.groupby('TagType').count())
# Out:
#                                     TagName  IsVersion  IsMajorVersion  \
# TagType
# admin-concept                       1        1          1
# admin-framework-core-feature        1        1          1
# admin-solution-build-sdk            1        1          1
# admin-solution-core-feature         1        1          1
# admin-tool                          11       11         11
# analytics-framework-api             1        1          1
# analytics-framework-data-concept    1        1          1
# analytics-solution-graph-library    1        1          1
# analytics-solution-server-solution  1        1          1
# analytics-tool                      1        1          1
# app-concept                         5        5          5
# app-framework-admin-tool            1        1          1
# app-framework-core-feature          3        3          3
# app-framework-core-library          3        3          3
# app-framework-database-feature      1        1          1
# app-framework-security-framework    1        1          1
# app-framework-server-solution       1        1          1
# app-framework-test-feature          1        1          1
# app-framework-web-feature           3        3          3
# audio-tool                          2        2          2
# blockchain-dev-solution             1        1          1
# build-concept                       2        2          2
# build-framework-core-feature        3        3          3
# build-solution                      1        1          1
# build-solution-feature              1        1          1
# business-concept                    1        1          1
# cloud-admin-solution                1        1          1
# cloud-admin-tool                    2        2          2
# cloud-analytics-solution            6        6          6
# cloud-api-solution                  3        3          3
# cloud-build-solution                1        1          1
# cloud-collab-solution               1        1          1
# cloud-compute-solution              2        2          2
# cloud-connector                     1        1          1
# cloud-connector-solution            1        1          1
# cloud-container-core-feature        1        1          1
# cloud-container-solution            2        2          2
# cloud-data-solution                 1        1          1
# cloud-database                      3        3          3
# cloud-database-tool                 1        1          1
# cloud-dev-solution                  3        3          3
# cloud-framework                     1        1          1
# cloud-iot-connector                 1        1          1
# cloud-management-solution           1        1          1
# cloud-messaging-solution            1        1          1
# cloud-ml-solution                   5        5          5
# cloud-notif-service                 1        1          1
# cloud-solution                      3        3          3
# cloud-solution-build-feature        1        1          1
# cloud-solution-core-feature         1        1          1
# cloud-versioning-solution           1        1          1
# cloud-web-framework                 1        1          1
# code-concept                        23       23         23
# code-framework                      1        1          1
# code-solution                       1        1          1
# code-tool                           1        1          1
# collab-solution                     2        2          2
# commerce-concept                    2        2          2
# commerce-solution                   1        1          1
# company                             1        1          1
# compute-framework                   2        2          2
# connector-api-core-feature          1        1          1
# connector-concept                   2        2          2
# connector-language                  1        1          1
# connector-solution                  1        1          1
# container-admin-tool                1        1          1
# container-core-feature              4        4          4
# container-solution                  3        3          3
# container-solution-admin-tool       1        1          1
# container-solution-core-feature     1        1          1
# container-tool                      1        1          1
# container-vm-tool                   1        1          1
# cs-concept                          2        2          2
# cv-concept                          2        2          2
# cv-solution                         1        1          1
# data-concept                        9        9          9
# data-framework                      1        1          1
# database                            3        3          3
# database-connector                  1        1          1
# database-core-feature               4        4          4
# database-framework-core-feature     1        1          1
# database-language                   1        1          1
# database-tool                       1        1          1
# db-concept                          3        3          3
# db-security-concept                 1        1          1
# deployment-concept                  2        2          2
# deployment-solution                 1        1          1
# deployment-solution-admin-tool      1        1          1
# deprecated-api                      1        1          1
# deprecated-lang-test-framework      1        1          1
# deprecated-library                  1        1          1
# deprecated-standard                 1        1          1
# design-concept                      17       17         17
# dev-solution                        5        5          5
# edu-platform                        1        1          1
# file-format                         7        7          7
# format                              2        2          2
# game-platform                       1        1          1
# gfx-concept                         2        2          2
# gfx-tool                            2        2          2
# hardware                            4        4          4
# hardware-concept                    3        3          3
# ide                                 4        4          4
# ide-tool                            1        1          1
# lang-admin-tool                     1        1          1
# lang-analytics-library              7        7          7
# lang-app-framework                  5        5          5
# lang-blockchain-framework           1        1          1
# lang-blockchain-library             3        3          3
# lang-blockchain-solution            1        1          1
# lang-build-framework                1        1          1
# lang-build-library                  1        1          1
# lang-build-solution                 4        4          4
# lang-build-tool                     1        1          1
# lang-business-library               1        1          1
# lang-cloud-sdk                      1        1          1
# lang-code-api                       1        1          1
# lang-code-feature                   1        1          1
# lang-code-library                   1        1          1
# lang-connector-feature              2        2          2
# lang-connector-framework            1        1          1
# lang-connector-library              3        3          3
# lang-core-api                       2        2          2
# lang-core-feature                   17       17         17
# lang-core-framework                 2        2          2
# lang-core-library                   17       17         17
# lang-cv-library                     2        2          2
# lang-data-feature                   1        1          1
# lang-data-library                   1        1          1
# lang-database-connector             3        3          3
# lang-database-feature               1        1          1
# lang-deployment-solution            1        1          1
# lang-dev-solution                   1        1          1
# lang-gfx-connector                  1        1          1
# lang-gfx-library                    3        3          3
# lang-graph-library                  2        2          2
# lang-microserv-framework            2        2          2
# lang-ml-framework                   1        1          1
# lang-ml-library                     7        7          7
# lang-mobile-library                 1        1          1
# lang-mobile-sdk                     3        3          3
# lang-mvc-framework                  1        1          1
# lang-network-library                1        1          1
# lang-security-feature               2        2          2
# lang-security-library               2        2          2
# lang-server-framework               1        1          1
# lang-server-library                 1        1          1
# lang-server-solution                1        1          1
# lang-test-concept                   1        1          1
# lang-test-framework                 1        1          1
# lang-test-tool                      1        1          1
# lang-ui-api                         1        1          1
# lang-ui-connector                   1        1          1
# lang-ui-feature                     2        2          2
# lang-ui-framework                   1        1          1
# lang-ui-library                     4        4          4
# lang-versioning-library             1        1          1
# lang-vr-library                     1        1          1
# lang-web-api                        3        3          3
# lang-web-client                     3        2          2
# lang-web-concept                    1        1          1
# lang-web-feature                    1        1          1
# lang-web-framework                  14       14         14
# lang-web-library                    2        2          2
# language                            18       18         18
# language-extension                  1        1          1
# language-version                    1        1          1
# ll-concept                          5        5          5
# ll-language                         1        1          1
# macro-language                      2        2          2
# management-solution                 3        3          3
# management-solution-core-feature    1        1          1
# management-tool                     1        1          1
# map-format                          4        4          4
# map-language                        1        1          1
# map-tool                            1        1          1
# math-concept                        21       21         21
# messaging-api                       1        1          1
# meta-language                       1        1          1
# microserv-solution                  2        2          2
# ml-cloud-solution                   1        1          1
# ml-concept                          14       14         14
# ml-framework                        2        2          2
# ml-framework-ui-library             1        1          1
# ml-solution                         6        6          6
# ml-tool                             1        1          1
# mobile-ar-framework                 2        2          2
# mobile-connector-library            1        1          1
# mobile-core-feature                 2        2          2
# mobile-core-library                 2        2          2
# mobile-framework                    1        1          1
# mobile-framework-ui-feature         1        1          1
# mobile-sdk                          2        2          2
# mobile-security-api                 1        1          1
# mobile-ui-library                   2        2          2
# mobile-ui-tool                      1        1          1
# mobile-vr-solution                  1        1          1
# mobile-web-client                   1        1          1
# network-concept                     2        2          2
# network-connector                   1        1          1
# network-security-tool               1        1          1
# os                                  2        2          2
# os-admin-tool                       2        2          2
# os-api                              1        1          1
# os-concept                          2        2          2
# os-connector                        1        1          1
# os-container-solution               1        1          1
# os-security-library                 1        1          1
# os-ui                               1        1          1
# person                              1        1          1
# platform-map-tool                   1        1          1
# query-language                      1        1          1
# scripting-language                  2        2          2
# security-concept                    5        5          5
# security-connector                  1        1          1
# security-framework                  3        3          3
# security-solution                   1        1          1
# security-tool                       1        1          1
# server-build-solution               1        1          1
# server-concept                      2        2          2
# server-solution                     1        1          1
# server-tool                         1        1          1
# standard                            6        6          6
# survey-service                      1        1          1
# template-language                   1        1          1
# test-concept                        1        1          1
# test-framework                      1        1          1
# test-framework-core-tool            1        1          1
# test-solution                       1        1          1
# ui                                  1        1          1
# ui-concept                          7        7          7
# versioning-concept                  3        3          3
# versioning-solution                 1        1          1
# vm-solution                         1        1          1
# vr-framework                        1        1          1
# vr-game-platform                    1        1          1
# vr-sdk                              1        1          1
# web-api                             1        1          1
# web-client                          1        1          1
# web-client-concept                  1        1          1
# web-commerce-solution               1        1          1
# web-concept                         12       12         12
# web-connector                       1        1          1
# web-framework                       1        1          1
# web-framework-admin-tool            1        1          1
# web-framework-api                   1        1          1
# web-framework-build-feature         1        1          1
# web-framework-build-framework       1        1          1
# web-framework-build-tool            1        1          1
# web-framework-code-library          1        1          1
# web-framework-code-tool             1        1          1
# web-framework-connector             6        6          6
# web-framework-core-api              1        1          1
# web-framework-core-feature          10       9          9
# web-framework-core-framework        1        1          1
# web-framework-core-library          8        8          8
# web-framework-database-library      1        1          1
# web-framework-dev-tool              1        1          1
# web-framework-microserv-library     1        1          1
# web-framework-network-library       1        1          1
# web-framework-server-framework      1        1          1
# web-framework-test-api              1        1          1
# web-framework-ui-feature            1        1          1
# web-framework-ui-framework          2        2          2
# web-framework-ui-library            6        6          6
# web-framework-web-framework         1        1          1
# web-framework-web-tool              1        1          1
# web-proxy                           3        3          3
# web-server-solution                 1        1          1
# web-solution                        1        1          1
# web-tool                            1        1          1
# website                             1        1          1
# wiki                                2        2          2
#
#                                     LangOrPlatform  HasAPIOrSupports  Excerpt
# TagType
# admin-concept                       0               0                 1
# admin-framework-core-feature        1               0                 1
# admin-solution-build-sdk            1               0                 1
# admin-solution-core-feature         1               0                 1
# admin-tool                          5               0                 11
# analytics-framework-api             1               0                 1
# analytics-framework-data-concept    1               0                 1
# analytics-solution-graph-library    1               0                 1
# analytics-solution-server-solution  1               0                 1
# analytics-tool                      0               1                 1
# app-concept                         0               0                 5
# app-framework-admin-tool            1               0                 1
# app-framework-core-feature          3               0                 3
# app-framework-core-library          3               0                 3
# app-framework-database-feature      1               0                 1
# app-framework-security-framework    1               0                 1
# app-framework-server-solution       1               0                 1
# app-framework-test-feature          1               0                 1
# app-framework-web-feature           3               0                 3
# audio-tool                          0               0                 2
# blockchain-dev-solution             0               0                 1
# build-concept                       0               0                 2
# build-framework-core-feature        3               0                 3
# build-solution                      0               0                 1
# build-solution-feature              1               0                 1
# business-concept                    0               0                 1
# cloud-admin-solution                1               1                 1
# cloud-admin-tool                    2               1                 2
# cloud-analytics-solution            6               6                 6
# cloud-api-solution                  3               2                 3
# cloud-build-solution                1               1                 1
# cloud-collab-solution               1               0                 1
# cloud-compute-solution              2               2                 2
# cloud-connector                     1               0                 1
# cloud-connector-solution            1               1                 1
# cloud-container-core-feature        1               0                 1
# cloud-container-solution            2               0                 2
# cloud-data-solution                 1               1                 1
# cloud-database                      3               3                 3
# cloud-database-tool                 1               0                 1
# cloud-dev-solution                  3               2                 3
# cloud-framework                     0               0                 1
# cloud-iot-connector                 1               1                 1
# cloud-management-solution           1               1                 1
# cloud-messaging-solution            1               1                 1
# cloud-ml-solution                   4               4                 5
# cloud-notif-service                 1               0                 1
# cloud-solution                      3               2                 3
# cloud-solution-build-feature        1               1                 1
# cloud-solution-core-feature         1               0                 1
# cloud-versioning-solution           1               0                 1
# cloud-web-framework                 1               0                 1
# code-concept                        0               0                 23
# code-framework                      0               0                 1
# code-solution                       0               0                 1
# code-tool                           0               0                 1
# collab-solution                     2               0                 2
# commerce-concept                    0               0                 2
# commerce-solution                   1               0                 1
# company                             0               0                 1
# compute-framework                   1               0                 2
# connector-api-core-feature          1               0                 1
# connector-concept                   0               0                 2
# connector-language                  1               0                 1
# connector-solution                  0               0                 1
# container-admin-tool                1               0                 1
# container-core-feature              4               0                 4
# container-solution                  2               0                 3
# container-solution-admin-tool       1               0                 1
# container-solution-core-feature     1               0                 1
# container-tool                      1               0                 1
# container-vm-tool                   1               0                 1
# cs-concept                          0               0                 2
# cv-concept                          0               0                 2
# cv-solution                         0               0                 1
# data-concept                        0               0                 9
# data-framework                      1               0                 1
# database                            2               0                 3
# database-connector                  1               0                 1
# database-core-feature               4               0                 4
# database-framework-core-feature     1               0                 1
# database-language                   1               0                 1
# database-tool                       0               0                 1
# db-concept                          0               0                 3
# db-security-concept                 0               0                 1
# deployment-concept                  0               0                 2
# deployment-solution                 0               0                 1
# deployment-solution-admin-tool      1               0                 1
# deprecated-api                      0               0                 1
# deprecated-lang-test-framework      1               0                 1
# deprecated-library                  0               0                 1
# deprecated-standard                 1               0                 1
# design-concept                      1               0                 17
# dev-solution                        1               0                 5
# edu-platform                        0               0                 1
# file-format                         3               0                 7
# format                              0               0                 2
# game-platform                       0               0                 1
# gfx-concept                         0               0                 2
# gfx-tool                            0               0                 2
# hardware                            2               0                 4
# hardware-concept                    0               1                 3
# ide                                 2               0                 4
# ide-tool                            1               0                 1
# lang-admin-tool                     1               0                 1
# lang-analytics-library              7               0                 7
# lang-app-framework                  5               0                 5
# lang-blockchain-framework           1               0                 1
# lang-blockchain-library             3               0                 3
# lang-blockchain-solution            1               0                 1
# lang-build-framework                1               0                 1
# lang-build-library                  1               0                 1
# lang-build-solution                 4               0                 4
# lang-build-tool                     1               0                 1
# lang-business-library               1               0                 1
# lang-cloud-sdk                      1               0                 1
# lang-code-api                       1               0                 1
# lang-code-feature                   1               0                 1
# lang-code-library                   1               0                 1
# lang-connector-feature              2               0                 2
# lang-connector-framework            1               0                 1
# lang-connector-library              3               0                 3
# lang-core-api                       2               0                 2
# lang-core-feature                   17              0                 17
# lang-core-framework                 2               0                 2
# lang-core-library                   17              0                 17
# lang-cv-library                     2               0                 2
# lang-data-feature                   1               0                 1
# lang-data-library                   1               0                 1
# lang-database-connector             3               0                 3
# lang-database-feature               1               0                 1
# lang-deployment-solution            1               0                 1
# lang-dev-solution                   1               0                 1
# lang-gfx-connector                  1               0                 1
# lang-gfx-library                    3               0                 3
# lang-graph-library                  2               0                 2
# lang-microserv-framework            2               0                 2
# lang-ml-framework                   1               0                 1
# lang-ml-library                     7               0                 7
# lang-mobile-library                 1               0                 1
# lang-mobile-sdk                     3               0                 3
# lang-mvc-framework                  1               0                 1
# lang-network-library                1               0                 1
# lang-security-feature               2               0                 2
# lang-security-library               2               0                 2
# lang-server-framework               1               0                 1
# lang-server-library                 1               0                 1
# lang-server-solution                1               0                 1
# lang-test-concept                   1               0                 1
# lang-test-framework                 1               0                 1
# lang-test-tool                      1               0                 1
# lang-ui-api                         1               0                 1
# lang-ui-connector                   1               0                 1
# lang-ui-feature                     2               0                 2
# lang-ui-framework                   1               0                 1
# lang-ui-library                     4               0                 4
# lang-versioning-library             1               0                 1
# lang-vr-library                     1               0                 1
# lang-web-api                        3               0                 3
# lang-web-client                     3               0                 3
# lang-web-concept                    1               0                 1
# lang-web-feature                    1               0                 1
# lang-web-framework                  14              0                 14
# lang-web-library                    2               0                 2
# language                            12              0                 18
# language-extension                  1               0                 1
# language-version                    1               0                 1
# ll-concept                          0               0                 5
# ll-language                         0               0                 1
# macro-language                      1               0                 2
# management-solution                 1               0                 3
# management-solution-core-feature    1               0                 1
# management-tool                     0               0                 1
# map-format                          1               0                 4
# map-language                        0               0                 1
# map-tool                            0               0                 1
# math-concept                        0               0                 21
# messaging-api                       1               0                 1
# meta-language                       0               0                 1
# microserv-solution                  1               0                 2
# ml-cloud-solution                   1               1                 1
# ml-concept                          0               0                 14
# ml-framework                        1               1                 2
# ml-framework-ui-library             1               0                 1
# ml-solution                         2               4                 6
# ml-tool                             0               0                 1
# mobile-ar-framework                 2               0                 2
# mobile-connector-library            1               0                 1
# mobile-core-feature                 2               0                 2
# mobile-core-library                 2               0                 2
# mobile-framework                    1               0                 1
# mobile-framework-ui-feature         1               0                 1
# mobile-sdk                          1               0                 2
# mobile-security-api                 1               0                 1
# mobile-ui-library                   2               0                 2
# mobile-ui-tool                      1               0                 1
# mobile-vr-solution                  1               0                 1
# mobile-web-client                   1               0                 1
# network-concept                     0               0                 2
# network-connector                   1               0                 1
# network-security-tool               0               0                 1
# os                                  1               0                 2
# os-admin-tool                       1               0                 2
# os-api                              1               0                 1
# os-concept                          0               0                 2
# os-connector                        1               0                 1
# os-container-solution               1               0                 1
# os-security-library                 1               0                 1
# os-ui                               1               0                 1
# person                              0               0                 1
# platform-map-tool                   1               0                 1
# query-language                      0               0                 1
# scripting-language                  1               0                 2
# security-concept                    0               0                 5
# security-connector                  0               0                 1
# security-framework                  1               0                 3
# security-solution                   1               0                 1
# security-tool                       0               0                 1
# server-build-solution               0               0                 1
# server-concept                      0               0                 2
# server-solution                     0               0                 1
# server-tool                         0               0                 1
# standard                            0               0                 6
# survey-service                      0               0                 1
# template-language                   1               0                 1
# test-concept                        0               0                 1
# test-framework                      1               0                 1
# test-framework-core-tool            1               0                 1
# test-solution                       0               0                 1
# ui                                  1               0                 1
# ui-concept                          0               0                 7
# versioning-concept                  0               0                 3
# versioning-solution                 0               0                 1
# vm-solution                         0               0                 1
# vr-framework                        1               0                 1
# vr-game-platform                    0               0                 1
# vr-sdk                              0               1                 1
# web-api                             1               0                 1
# web-client                          0               0                 1
# web-client-concept                  0               0                 1
# web-commerce-solution               0               0                 1
# web-concept                         1               0                 12
# web-connector                       1               0                 1
# web-framework                       1               0                 1
# web-framework-admin-tool            1               0                 1
# web-framework-api                   1               0                 1
# web-framework-build-feature         1               0                 1
# web-framework-build-framework       1               0                 1
# web-framework-build-tool            1               0                 1
# web-framework-code-library          1               0                 1
# web-framework-code-tool             1               0                 1
# web-framework-connector             6               0                 6
# web-framework-core-api              1               0                 1
# web-framework-core-feature          10              0                 10
# web-framework-core-framework        1               0                 1
# web-framework-core-library          8               0                 8
# web-framework-database-library      1               0                 1
# web-framework-dev-tool              1               0                 1
# web-framework-microserv-library     1               0                 1
# web-framework-network-library       1               0                 1
# web-framework-server-framework      1               0                 1
# web-framework-test-api              1               0                 1
# web-framework-ui-feature            1               0                 1
# web-framework-ui-framework          2               0                 2
# web-framework-ui-library            6               0                 6
# web-framework-web-framework         1               0                 1
# web-framework-web-tool              1               0                 1
# web-proxy                           1               0                 3
# web-server-solution                 1               0                 1
# web-solution                        1               0                 1
# web-tool                            0               0                 1
# website                             0               0                 1
# wiki                                1               0                 2

# %%
synonyms_dict = {'db': 'database',
                 'll':'lowlevel'}

# %%
tag_topics_and_types = pd.merge(matched_tag_types, matched_tag_types.apply(lambda x: 
                       pd.Series(get_umbrella_topic(x['TagType'])), axis=1).\
                       rename(columns={0:'topic',1:'type'}), left_index=True, right_index=True)
tag_topics_and_types.head()
# Out:
#                   TagName IsVersion IsMajorVersion                TagType  \
# 0                  vuejs2      True           True     lang-web-framework
# 1  google-cloud-firestore     False          False         cloud-database
# 2                json.net     False          False     lang-web-framework
# 3                  ionic3      True           True        lang-mobile-sdk
# 4           mongodb-query     False          False  database-core-feature
#
#   LangOrPlatform                                   HasAPIOrSupports  \
# 0         vue.js                                                NaN
# 1   google-cloud  c++,node.js,javascript,android,swift,objective...
# 2           .net                                                NaN
# 3     javascript                                                NaN
# 4        mongodb                                                NaN
#
#                                              Excerpt     topic       type
# 0  Use this tag for questions specific to version...       web  framework
# 1  Cloud Firestore is an auto-scaling real-time d...     cloud   database
# 2  Json.NET (also known as Newtonsoft.Json) is a ...       web  framework
# 3  Ionic 3 is the newer version of Ionic, an open...    mobile        sdk
# 4  This tag is for questions related to querying ...  database    feature

# %%
merged_both_after_warmup.head()
# Out:
#                   TagName                             author  \
# 0                  vuejs2                     ABOUT YOU GmbH
# 1  google-cloud-firestore     AURO NEW TRANSPORT CONCEPT SL.
# 2                json.net  BridgePay Network Solutions,  LLC
# 3                  ionic3                   Alpha Telefonica
# 4           mongodb-query                             NextVR
#
#               ad_date         course_date  TagCount  \
# 0 2016-12-02 17:51:14 2017-02-23 19:47:36     15043
# 1 2017-12-18 14:40:48 2017-07-03 12:21:18     11223
# 2 2018-04-27 06:00:50 2017-09-19 10:56:37     10294
# 3 2017-09-01 02:02:18 2016-11-19 21:36:34     10284
# 4 2017-10-06 14:22:34 2017-07-13 08:36:31     10000
#
#                                              Excerpt         TagWikiDate  \
# 0  Use this tag for questions specific to version... 2016-10-10 13:24:27
# 1  Cloud Firestore is an auto-scaling real-time d... 2017-10-03 16:20:05
# 2  Json.NET (also known as Newtonsoft.Json) is a ... 2011-02-05 12:22:34
# 3  Ionic 3 is the newer version of Ionic, an open... 2017-04-14 04:59:11
# 4  This tag is for questions related to querying ... 2012-05-06 06:11:17
#
#           TagFirstUseDate           TagNthUseDate         nth_ad_date  \
# 0 2016-02-27 01:15:56.420 2016-09-07 22:58:01.873 2017-09-01 20:38:12
# 1 2017-07-05 16:23:41.513 2017-10-03 20:46:37.610 2018-02-07 18:37:35
# 2 2008-09-20 00:44:26.330 2009-01-28 22:35:16.750                 NaT
# 3 2016-01-13 07:09:26.983 2016-06-06 11:40:24.703 2018-03-14 13:42:57
# 4 2010-02-19 19:07:14.197 2010-07-08 22:41:20.070 2018-04-17 09:32:24
#
#       nth_course_date  difference_in_days  difference_from_tag_first_use  \
# 0 2017-09-06 09:25:07                  83                            279
# 1 2018-03-28 06:12:35                -169                             -3
# 2 2018-11-11 13:25:40                -220                           3286
# 3 2017-05-06 20:50:11                -286                            311
# 4 2018-06-18 10:30:47                 -86                           2700
#
#    difference_from_tag_wiki  \
# 0                        53
# 1                       -93
# 2                      2417
# 3                      -146
# 4                      1894
#
#                                           ExcerptVec  AdFirst
# 0  [-0.04369566704346133, 0.02590556795309697, -0...     True
# 1  [-0.09344200964551419, -0.01607348897960037, 0...    False
# 2  [-0.1431919313967228, -0.022353296540677546, -...    False
# 3  [-0.07675749761983752, 0.04825124121271074, -0...    False
# 4  [-0.12596115039195865, 0.012548449914902449, -...    False

# %%
def create_s_first_proportion_barcharts(adoption_seq_df, tag_types_df, types_to_handle, 
                                        column_to_use='topic', type_equivalence_dict=None):
    results = list()
    if type_equivalence_dict is not None:
        types_to_handle = [type_equivalence_dict.get(x, x) for x in types_to_handle]
    for tag_type in types_to_handle:
        tag_names = tag_types_df.loc[tag_types_df[column_to_use] == tag_type].TagName.values
        results.append(get_all_proportions(get_subset_of_tags(adoption_seq_df, tag_names), 
                                           'short_adoption_seq'))
    fig = plt.figure(figsize=(20,20))
    ax = [fig.add_subplot(211), fig.add_subplot(212)]
    ax[0].bar(x=types_to_handle, height=[x[0] for x in results], color='blue')
    ax[0].set_yticks(np.arange(0,1.1,0.1))

    ax[1].bar(x=types_to_handle, height=[x[3] for x in results], color='blue')
    ax[1].set_yticks(np.arange(0,max([x[3] for x in results])+5,5))
    for axis in ax:
        axis.tick_params(axis='x', rotation=45)
        axis.tick_params(axis='both', which='major', labelsize=15)
    ax[1].set_xlabel('Type of tag', fontsize=15)
    ax[0].set_ylabel('Proportion of StackOverflow-first\n tags within topic', fontsize=15)
    ax[1].set_ylabel('Total number of tags within topic', fontsize=15)
    plt.subplots_adjust(hspace=0.35)
    plt.show()

# %%
tag_subset = tags_from_one_year_before_warmup
top_n_topics = pd.DataFrame(get_subset_of_tags(tag_topics_and_types, tag_subset)['topic'].\
                            value_counts()).reset_index().\
            rename(columns={'index':'topic', 'topic': 'count'}).head(20).topic.values
create_s_first_proportion_barcharts(adoption_sequences, 
                get_subset_of_tags(tag_topics_and_types, tag_subset), top_n_topics)

# %% [markdown]
# What does this tell us? That generally, more programming-heavy tags have a much higher tendency to appear first on Stack Overflow, and tags that don't necessarily involve developing applications have a lower tendency, although many types still end up appearing first on Stack Overflow (but not as overwhelmingly as, say, web or mobile topics). In particular, it's notable that topics leaning more towards administration (e.g. database, container, especially the latter) have lower than 50% ratios; this might be because there are other StackExchange websites for _non-programmatic_ questions, which would be a very interesting result; indeed, if we can prove that StackExchange as a whole is really fast in pretty much everything, then we will have taken one step further towards a predictive model. Our statement is a bit of an overgeneralisation though, given the numbers; here we can only be confident about web, with cloud and ml also being kinda reliable.
#
# If we look at two years before the warmup (approximately where we've put the end of Udemy's warmup period), we see that most topics that are programming-heavy are at least at the general Udemy-StackOverflow level (70% SO-first).

# %% [markdown]
# ### TODO: Other groupings of tags, and mapping similar topics/types to the same word.

# %%
tag_topics_and_types['topic'].value_counts().to_dict()
# Out:
# {'web': 98,
#  'cloud': 47,
#  'core': 38,
#  'ml': 33,
#  'code': 29,
#  'app': 24,
#  'math': 21,
#  'mobile': 21,
#  'generalpurpose': 20,
#  'ui': 17,
#  'design': 17,
#  'admin': 16,
#  'security': 15,
#  'database': 15,
#  'build': 14,
#  'analytics': 12,
#  'data': 12,
#  'container': 12,
#  'connector': 11,
#  'os': 11,
#  'gfx': 8,
#  'server': 8,
#  'file': 7,
#  'hardware': 7,
#  'test': 7,
#  'blockchain': 6,
#  'll': 6,
#  'dev': 6,
#  'standard': 6,
#  'map': 6,
#  'deployment': 5,
#  'ide': 5,
#  'network': 5,
#  'versioning': 5,
#  'cv': 5,
#  'management': 5,
#  'microserv': 4,
#  'db': 4,
#  'vr': 4,
#  'commerce': 3,
#  'wiki': 2,
#  'cs': 2,
#  'graph': 2,
#  'audio': 2,
#  'compute': 2,
#  'collab': 2,
#  'macro': 2,
#  'scripting': 2,
#  'format': 2,
#  'business': 2,
#  'query': 1,
#  'website': 1,
#  'template': 1,
#  'messaging': 1,
#  'edu': 1,
#  'survey': 1,
#  'platform': 1,
#  'meta': 1,
#  'game': 1,
#  'vm': 1,
#  'mvc': 1}

# %%
tag_topics_and_types['type'].value_counts().to_dict()
# Out:
# {'concept': 155,
#  'library': 90,
#  'solution': 82,
#  'feature': 71,
#  'framework': 55,
#  'tool': 48,
#  'language': 31,
#  'connector': 18,
#  'api': 15,
#  'format': 11,
#  'sdk': 8,
#  'client': 5,
#  'proxy': 3,
#  'database': 3,
#  'platform': 3,
#  'service': 2,
#  'ui': 1}

# %%
pd.concat([tag_topics_and_types['LangOrPlatform'].dropna().apply(lambda x: x.split(',')).apply(pd.Series).\
          unstack().reset_index(drop=True), 
          tag_topics_and_types['HasAPIOrSupports'].dropna().apply(lambda x: x.split(',')).apply(pd.Series).\
          unstack().reset_index(drop=True)]).dropna().value_counts().to_dict()
# Out:
# {'python': 60,
#  'java': 47,
#  '.net': 32,
#  'node.js': 32,
#  'javascript': 31,
#  'android': 27,
#  'php': 24,
#  'c++': 22,
#  'go': 22,
#  'azure': 20,
#  'ruby': 18,
#  'react': 16,
#  'ios': 14,
#  'amazon': 14,
#  'angular': 13,
#  'r': 12,
#  'unix': 11,
#  'kubernetes': 9,
#  'docker': 9,
#  'google-cloud': 9,
#  'scala': 8,
#  'vue.js': 8,
#  'sql': 8,
#  'spring': 8,
#  'swift': 7,
#  'c': 7,
#  'unity': 7,
#  'mongodb': 7,
#  'windows': 5,
#  'spark': 5,
#  'powershell': 4,
#  'c#': 4,
#  'html': 4,
#  'google': 4,
#  'css': 4,
#  'typescript': 3,
#  'kotlin': 3,
#  'jenkins': 3,
#  'ecmascript': 3,
#  'microsoft': 3,
#  'django': 3,
#  'objective-c': 3,
#  'unreal-engine': 2,
#  'julia': 2,
#  'sling': 2,
#  'laravel': 2,
#  'asp.net': 2,
#  'redux': 2,
#  'chef': 2,
#  'ruby-on-rails': 2,
#  'maven': 2,
#  'rust': 2,
#  'facebook': 2,
#  'jquery': 2,
#  'wordpress': 2,
#  'graphql': 2,
#  'tinkerpop': 1,
#  'racket': 1,
#  'ajax': 1,
#  'office': 1,
#  'zos': 1,
#  'pig': 1,
#  'hibernate': 1,
#  'drupal': 1,
#  'mesos': 1,
#  'ansible': 1,
#  'ddl': 1,
#  'testng': 1,
#  'hive': 1,
#  'abap': 1,
#  'kafka': 1,
#  'mason': 1,
#  'redis': 1,
#  'struts2': 1,
#  'arcgis': 1,
#  'heroku': 1,
#  'html5': 1,
#  'perl': 1,
#  'clojure': 1,
#  'delphi': 1,
#  'symfony': 1,
#  'akka': 1,
#  'bootstrap': 1,
#  'apex': 1,
#  'ember.js': 1,
#  'zig': 1,
#  'hadoop': 1,
#  'ros': 1,
#  'slack': 1,
#  'channel': 1,
#  'joomla': 1,
#  'express': 1,
#  'ocaml': 1,
#  'elasticsearch': 1,
#  'json': 1,
#  'osx': 1,
#  'rpi': 1,
#  'haskell': 1,
#  'oracle': 1,
#  'electron': 1,
#  'groovy': 1,
#  'f#': 1,
#  'semantic-ui': 1,
#  'cassandra': 1,
#  'gradle': 1}

# %%
matched_tag_types.loc[matched_tag_types.LangOrPlatform.isna() & 
                      matched_tag_types.TagType.apply(lambda x: '-concept' not in x)]
# Out:
#                      TagName IsVersion IsMajorVersion  \
# 37                     antlr     False          False
# 56                      nsis     False          False
# 59                  keycloak     False          False
# 70           barcode-scanner     False          False
# 71               iis-express     False          False
# 88                       elf     False          False
# 95                       lex     False          False
# 101                      ini     False          False
# 115                shapefile     False          False
# 119                   netcdf     False          False
# 121          apache-zeppelin     False          False
# 139                  keytool     False          False
# 144                  traefik     False          False
# 152       visual-studio-2019      True           True
# 154                      rdp     False          False
# 156                 jsonpath     False          False
# 162                  java-11      True           True
# 166                sas-macro     False          False
# 167  informatica-powercenter     False          False
# 173                  tfs2017     False          False
# 174                      avx     False          False
# 185                     neon     False          False
# 188                    istio     False          False
# 189                 opensuse     False          False
# 222                    sinch     False          False
# 237                  netlify     False          False
# 238                powerapps     False          False
# 244                   coreml     False          False
# 248                  truffle     False          False
# 251                  netstat     False          False
# ..                       ...       ...            ...
# 482                 airtable     False          False
# 489                    knuth     False          False
# 494                   archer     False          False
# 495                     idoc     False          False
# 497                 snowball     False          False
# 499                     dyno     False          False
# 504                  steamvr     False          False
# 510                  openvas     False          False
# 512                      sld     False          False
# 526                    siege     False          False
# 527                 highrise     False          False
# 529                    quora     False          False
# 531                     cucm     False          False
# 532                 createml     False          False
# 537             image-viewer     False          False
# 542                     pvcs     False          False
# 548                       n3     False          False
# 561                 insomnia     False          False
# 571                     crdt     False          False
# 578                 manifold     False          False
# 594               geopackage     False          False
# 597                map-basic     False          False
# 604                   reaper     False          False
# 606                      npn     False          False
# 607                   sysdig     False          False
# 608               tia-portal     False          False
# 614          management-pack     False          False
# 624  relationship-extraction     False          False
# 625              loadleveler     False          False
# 628                  neptune     False          False
#
#                      TagType LangOrPlatform        HasAPIOrSupports  \
# 37            code-framework            NaN                     NaN
# 56            build-solution            NaN                     NaN
# 59        security-framework            NaN                     NaN
# 70                  hardware            NaN                     NaN
# 71           server-solution            NaN                     NaN
# 88               file-format            NaN                     NaN
# 95             code-solution            NaN                     NaN
# 101              file-format            NaN                     NaN
# 115               map-format            NaN                     NaN
# 119                 standard            NaN                     NaN
# 121           analytics-tool            NaN  sql,python,scala,spark
# 139            security-tool            NaN                     NaN
# 144                web-proxy            NaN                     NaN
# 152                      ide            NaN                     NaN
# 154                 standard            NaN                     NaN
# 156           query-language            NaN                     NaN
# 162                 language            NaN                     NaN
# 166            meta-language            NaN                     NaN
# 167       connector-solution            NaN                     NaN
# 173             dev-solution            NaN                     NaN
# 174                 language            NaN                     NaN
# 185              ll-language            NaN                     NaN
# 188       microserv-solution            NaN                     NaN
# 189                       os            NaN                     NaN
# 222               mobile-sdk            NaN                     NaN
# 237      deployment-solution            NaN                     NaN
# 238             dev-solution            NaN                     NaN
# 244             ml-framework            NaN       objective-c,swift
# 248  blockchain-dev-solution            NaN                     NaN
# 251               admin-tool            NaN                     NaN
# ..                       ...            ...                     ...
# 482                 database            NaN                     NaN
# 489                   person            NaN                     NaN
# 494             dev-solution            NaN                     NaN
# 495       scripting-language            NaN                     NaN
# 497                 language            NaN                     NaN
# 499       container-solution            NaN                     NaN
# 504         vr-game-platform            NaN                     NaN
# 510       security-framework            NaN                     NaN
# 512               map-format            NaN                     NaN
# 526                 web-tool            NaN                     NaN
# 527      management-solution            NaN                     NaN
# 529                  website            NaN                     NaN
# 531          management-tool            NaN                     NaN
# 532              ml-solution            NaN                   swift
# 537                 gfx-tool            NaN                     NaN
# 542      versioning-solution            NaN                     NaN
# 548                 language            NaN                     NaN
# 561               web-client            NaN                     NaN
# 571                   format            NaN                     NaN
# 578                 map-tool            NaN                     NaN
# 594               map-format            NaN                     NaN
# 597             map-language            NaN                     NaN
# 604               audio-tool            NaN                     NaN
# 606                 standard            NaN                     NaN
# 607               admin-tool            NaN                     NaN
# 608               admin-tool            NaN                     NaN
# 614               admin-tool            NaN                     NaN
# 624                  ml-tool            NaN                     NaN
# 625            os-admin-tool            NaN                     NaN
# 628              ml-solution            NaN                python,r
#
#                                                Excerpt
# 37   ANTLR, ANother Tool for Language Recognition, ...
# 56   This tag is used for questions about the open ...
# 59   Integrated Single Sign On (SSO) and Identity M...
# 70   A barcode reader (or barcode scanner) is an el...
# 71   IIS Express is the developer version of full I...
# 88   ELF stands for Executable and Linkable Format,...
# 95   Lex is a computer program that generates lexic...
# 101  The INI file format includes text-based initia...
# 115  The Esri shapefile or simply a shapefile is a ...
# 119  NetCDF (Network Common Data Form) is a set of ...
# 121  Apache Zeppelin is a web-based notebook that e...
# 139  Key and Certificate Management Tool: manages a...
# 144  Træfɪk is a modern HTTP reverse proxy and load...
# 152  Visual Studio 2019 is a version of Microsoft's...
# 154  Remote Desktop Protocol (RDP) is a proprietary...
# 156  JSONPath is a means of using XPath-like syntax...
# 162  Use this tag for questions specific to Java 11...
# 166  A metaprogramming language used in the SAS sui...
# 167  Informatica Powercenter is an ETL (Extract, Tr...
# 173  Use this tag for version specific questions ab...
# 174  Advanced Vector Extensions (AVX) is an extensi...
# 185  NEON is a vector-processing instruction set fo...
# 188  Istio is an open-source platform for managing ...
# 189  openSUSE is a free and opensource general purp...
# 222  Use the Sinch SDKs and APIs to enhance your ap...
# 237  Ask questions about the Netlify setup, config ...
# 238  PowerApps is an enterprise service for innovat...
# 244  Apple's Core ML framework and tools for making...
# 248  Development environment, testing framework and...
# 251  netstat (network statistics) is a command-line...
# ..                                                 ...
# 482  Questions related to interacting with Airtable...
# 489  Donald E. Knuth is a computer scientist, best ...
# 494  Archer refers to the (RSA) Archer GRC Platform...
# 495  IDOC is a proprietary server site scripting la...
# 497  Snowball is a small language for writing stemm...
# 499  Heroku Dynos are lightweight containers for ru...
# 504  Steam is an internet distribution plattform fo...
# 510  OpenVAS is a framework of several services and...
# 512  A Styled Layer Descriptor (SLD) is an XML sche...
# 526  Siege is an http/https regression testing and ...
# 527              Highrise is a CRM for HR specialists.
# 529  Quora is a community-driven question-and-answe...
# 531  Cisco Unified Communications Manager (CUCM), f...
# 532  Create ML is a tool created by Apple used to c...
# 537  Image viewer is an application which displays ...
# 542  Synergex PVCS is a collection of tools that pr...
# 548  N3 stands for Notation 3, an assertion and log...
# 561  Insomnia is a desktop client for interacting w...
# 571                   Commutative Replicated Data Type
# 578  Manifold System is a geographic information sy...
# 594  A GeoPackage is an open, standards-based, plat...
# 597  MapBasic is a programming language for the cre...
# 604  REAPER is digital audio workstation software: ...
# 606  The Next Protocol Negotiation extension (NPN) ...
# 607  Linux system exploration and troubleshooting t...
# 608  The TIA-Portal tag describes the SIMATIC STEP ...
# 614  SCOM (System Center Operation Manager) managem...
# 624  Relationship Extraction is an IBM Watson Servi...
# 625  LoadLeveler is a job scheduler written by IBM,...
# 628  Neptune is a machine learning lab by deepsense...
#
# [101 rows x 7 columns]

# %% [markdown]
# Notes:
# * The `data` category ranges from data structures to signals and communications.
# * The `ll` category is for low-level concepts, such as opcodes.
# * The `os` category is more directly related to operating systems since `ll` is now separate.
# * The `admin` category is relatively broad: ranging from small cmd programs (like htop) to entire admin solutions.

# %%
# # This part was used to map tag types that were entirely wrong to their new types.
# mapping = {x:x for x in matched_tag_types.TagType.unique()}
# mapping.update({'build-soluton': 'build-solution',
#                 'collaborative-solution': 'collab-solution',
#                 'computation-framework': 'compute-framework',
#                 'crypto-concept': 'security-concept',
#                 'development-solution': 'dev-solution',
#                 'dev-stack': 'dev-solution',
#                 'doc': 'collab-solution',
#                 'gui': 'ui',
#                 'help-solution': 'management-solution',
#                 'language-implementation': 'library',
#                 'lbrary': 'library',
#                 'libray': 'library',
#                 'platform-feature': 'solution-feature',
#                 'project-solution': 'dev-solution',
#                 'protocol': 'standard',
#                 'source-control': 'versioning-solution',
#                 'web-server': 'server-solution'})

# %%
#matched_tag_types.loc[matched_tag_types.TagType.apply(lambda x: 'web-solution' in x)]

# %%
# matched_tag_types['TagType'] = matched_tag_types['TagType'].apply(lambda x: mapping[x])

# %%
# matched_tag_types.to_csv('/home/yazdania/so_jobs_analysis/tags_to_categorise.csv')

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', -1):
#     display(pd.merge(matched_tag_types, merged_both_after_warmup[['TagName', 'Excerpt']], on='TagName'))

# %%
# individual_tag_mapping = {matched_tag_types.TagName.values[i]: matched_tag_types.TagType.values[i] 
#                           for i in range(matched_tag_types.shape[0])}
# individual_tag_mapping.update({'google-cloud-firestore': 'cloud-database', 'google-cloud-functions': 'cloud-compute-solution', 'pyqt5': 'ui-api', 
#                                'wxpython': 'ui-connector', 'retrtofit2': 'web-client', 'azure-functions': 'cloud-compute-solution', 'javamail': 'web-api', 
#                                'wmi': 'os-api', 'azure-cosmosdb': 'cloud-database', 'antlr': 'compiler-framework', 'aws-api-gateway': 'cloud-api-solution', 
#                                'vuex': 'framework-library', 'amazon-cognito': 'cloud-data-solution', 'asp.net-core-webapi': 'web-api', 'angular-material2': 'framework-library', 
#                                'azure-service-fabric': 'cloud-dev-solution', 'angular2-forms': 'framework-concept', 'azure-pipelines': 'cloud-build-solution', 'vuetify.js': 'framework-framework', 
#                                'ngrx': 'framework-library', 'nsis': 'build-solution', 'angular2-services': 'framework-concept', 'setuptools': 'build-library', 'roslyn': 'compiler-api', 'nuxt.js': 'framework-framework', 
#                                'gcloud': 'admin-tool', 'emgucv': 'gfx-connector', 'dask': 'analytics-library', 'resttemplate': 'framework-feature', 'azure-application-insights': 'cloud-analytics-solution', 'caliburn.micro': 'mvc-framework', 
#                                'react-hooks': 'framework-feature', 'amazon-sns': 'cloud-notif-service', 'spring-webflux': 'framework-feature', 'gatsby': 'framework-library', 'statsmodels': 'analytics-library', 
#                                'image-segmentation': 'gfx-concept', 'glfw': 'gfx-library', 'firebase-analytics': 'cloud-analytics-solution', 'tensorboard': 'framework-library', 'next.js': 'framework-framework', 'redux-saga': 'framework-connector', 
#                                'spacy': 'ml-library', 'code-formatting': 'design-concept', 'xgboost': 'ml-library', 'jacoco': 'test-tool', 'owl-carousel': 'framework-library', 'react-apollo': 'framework-ui-library', 'shapefile': 'map-format', 
#                                'azure-powershell': 'cloud-admin-solution', 'kubectl': 'container-cmd-tool', 'apache-zeppelin': 'analytics-tool', 'azure-data-lake': 'cloud-analytics-solution', 'razor-pages': 'framework-feature', 'androidx': 'mobile-library', 
#                                'android-camera2': 'mobile-library', 'unit-of-work': 'design-concept', 'keytool': 'security-tool', 'azure-iot-hub': 'cloud-connector-solution', 'apollo-client': 'ui-library', 'traefik': 'web-proxy', 'scikit-image': 'cv-library', 
#                                'arcore':'ar-framework', 'amazon-athena': 'cloud-database-tool', 'rbenv': 'versioning-library', 'force-layout': 'ui-concept', 'gradle-plugin': 'solution-concept', 'minikube': 'container-vm-tool', 'glew': 'gfx-library', 'ionic-native': 'mobile-sdk', 
#                                'informatica-powercenter': 'data-connector-solution', 'cpython': 'lang-implementation', 'azure-api-management': 'cloud-api-solution', 'react-native-navigation': 'framework-library', 'autosuggest': 'ui-concept', 'android-keystore': 'mobile-api', 
#                                'virtuemart': 'commerce-solution', 'android-jetpack': 'mobile-sdk', 'sparkr': 'analytics-library', 'spring-cloud-config': 'server-solution', 'istio': 'microserv-solution', 'arm-template': 'cloud-solution-feature', 'vue-cli': 'admin-tool', 
#                                'ambari': 'analytics-server-solution', 'actioncable': 'framework-library', 'aws-iot': 'cloud-connector-solution', 'ngrx-store': 'framework-library', 'azure-virtual-network': 'web-proxy', 'web3': 'blockchain-framework', 'ngx-bootstrap': 'framework-connector', 
#                                'mgo': 'database-connector', 'image-compression': 'cv-concept', 'semantic-ui-react': 'framework-ui-library', 'firedac': 'connector-library', 'topojson': 'map-format', 'sinch': 'mobile-sdk', 'ngrx-effects': 'framework-library', 'node-sass': 'framework-connector', 
#                                'hibernate-annotations': 'library-concept', 'angular-template': 'framework-concept', 'react-native-firebase': 'framework-library', 'kotlin-android-extensions': 'mobile-library', 'cntk': 'ml-library', 'powerapps': 'dev-solution', 
#                                'tpl-dataflow': 'framework-library', 'react-router-redux': 'framework-library', 'web3js': 'blockchain-library', 'truffle':'blockchain-dev-solution', 'oidc': 'security-connector', 'aws-codebuild': 'cloud-dev-solution', 
#                                'yolo': 'cv-library', 'azure-cognitive-services': 'cloud-ml-solution', 'uicontrol': 'mobile-framework-feature', 'mockmvc': 'mvc-framework-feature', 'amazon-lex': 'cloud-ml-solution', 'undertow': 'web-server-solution', 'windows-firewall': 'security-solution', 
#                                'vmware-workstation': 'vm-solution', 'workbox': 'server-build-solution', 'replicaset': 'database-feature', 'laravel-dusk':'framework-test-api', 'azure-kubernetes': 'cloud-container-solution', 'azure-api-apps': 'cloud-api-solution', 'rpa': 'ml-concept', 
#                                'changeset': 'versioning-concept', 'azure-container-service': 'cloud-container-solution', 'pwm': 'hardware-concept', 'rssi': 'comms-concept', 'react-context': 'framework-feature', 'holoviews': 'analytics-library', 'aot': 'management-platform-feature', 
#                                'arcmap': 'map-tool', 'read-the-docs': 'wiki', 'prisma': 'database-connector', 'snort': 'network-security-tool', 'runtime-permissions': 'mobile-feature', 'fabric8': 'microserv-solution', 'qt3d': 'gfx-library', 'elastica': 'analytics-library', 'saga': 'design-concept', 
#                                'background-subtraction': 'cv-concept', 'element-ui': 'framework-library', 'ack': 'compile-tool', 'bloc': 'design-concept', 'go-ethereum': 'blockchain-library', 'quantization': 'math-concept', 'swift-package-manager': 'build-solution', 'design-by-contract':'design-concept', 
#                                'vbox': 'library-feature', 'geth': 'blockchain-library', 'seq2seq': 'ml-library', 'recompose': 'framework-library', 'monorepo': 'versioning-concept', 'color-mapping': 'ui-concept', 'elasticsearch-query': 'framework-concept', 'polly': 'framework-library', 
#                                'visual-recognition': 'cv-solution', 'row-level-security': 'database-security-concept', 'free-monad': 'design-concept', 'vue-material': 'framework-framework', 'google-slides': 'cloud-collab-solution', 'volusion': 'web-commerce-solution', 'bounded-contexts': 'design-concept', 
#                                'graphframes': 'analytics-library', 'metamask':'web-connector', 'dl4j': 'ml-library', 'natural-join': 'database-concept', 'amazon-quicksight': 'cloud-analytics-solution', 'specification-pattern': 'design-concept', 'statechart': 'design-concept', 'pprof':'server-library', 'sku': 'business-concept', 
#                                'deform': 'web-library', 'mapping-model': 'design-concept', 'reportng': 'framework-tool', 'srv':'tech-concept', 'blue-green-deployment': 'deployment-concept', 'symfony-flex': 'admin-tool', 'sld': 'map-format', 'adaptive-ui': 'mobile-ui', 'flowable':'business-library', 'seneca':'microserv-library', 
#                                'private-subnet':'network-concept', 'highrise': 'management-solution', 'cucm': 'business-tool', 'image-viewer': 'gfx-tool', 'hapi.js': 'framework-server-framework', 'rook': 'web-library', 'radium': 'framework-library', 'canary-deployment': 'deployment-concept', 'pbr': 'gfx-concept', 
#                                'jquery-ui-plugins': 'framework-ui-concept', 'contract-first': 'design-concept', 'ispf': 'admin-tool', 'react-fiber': 'framework-library', 'no-framework': 'design-concept', '.net-core-1.1': 'web-framework', 'data-access-object': 'design-concept', 'pallet': 'deployment-solution', 'automatic-failover': 'database-concept', 
#                                'slab': 'framework-feature', 'manifold': 'map-tool', 'account-linking':'database-concept', 'floating-ip': 'network-concept', 'geopackage': 'map-format', 'map-basic': 'map-language', 'connection-points': 'connector-concept', 'staging-table': 'data-concept', 'reaper': 'audio-tool', 'zen-of-python': 'design-concept',
#                                'koa.js': 'connector-framework', 'authentication-flows':'framework-security-framework', 'hibernate-query': 'database-language', 'prototype-scope': 'framework-concept', 'management-pack': 'admin-tool', 'haxl':'connector-library', 'code-elimination': 'compile-concept', 'enclose': 'framework-compile-library', 
#                                'dfd':'design-concept', 'codemod': 'compile-tool', 'loadleveler': 'tool', 'mix-and-match': 'lang-concept', 'connect-rest': 'framework-connector'})
# matched_tag_types['TagTypeRevised'] = matched_tag_types.TagName.apply(lambda x: individual_tag_mapping[x])

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', -1):
#     display(pd.merge(matched_tag_types, merged_both_after_warmup[['TagName', 'Excerpt']], on='TagName'))

# %%
# pd.merge(matched_tag_types, merged_both_after_warmup[['TagName', 'Excerpt']], on='TagName').\
#                 to_csv('/home/yazdania/so_jobs_analysis/tags_to_categorise.csv')
